# %% [markdown]
# # Task 5 - Attention-based Neural Machine Translation
# Team Members
#
# *   Libin Kutty
# *   Viju Sudhi
# *   Ritu Gahir

# %%
# %tensorflow_version 2.x

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import pandas as pd
import os
import io
import time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(os.getcwd())
os.chdir("/content/drive/My Drive/Colab Notebook/IDL/")
print(os.getcwd())
# Out:
# /content
# /content/drive/My Drive/Colab Notebook/IDL

# %%
dataFile = os.getcwd()
path = os.path.join(dataFile, 'hin-eng/hin.txt')

data = pd.read_csv(path, sep="\t", header=None)
data.columns = ["eng", "hin", "info"]

# %%
data
# Out:
#                                                     eng  ...                                               info
# 0                                                  Wow!  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 1                                                 Help!  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #4...
# 2                                                 Jump.  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #6...
# 3                                                 Jump.  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #6...
# 4                                                 Jump.  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #6...
# ...                                                 ...  ...                                                ...
# 2768  If you go to that supermarket, you can buy mos...  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #6...
# 2769  The passengers who were injured in the acciden...  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #4...
# 2770  Democracy is the worst form of government, exc...  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #1...
# 2771  If my boy had not been killed in the traffic a...  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #3...
# 2772  When I was a kid, touching bugs didn't bother ...  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #2...
#
# [2773 rows x 3 columns]

# %%
src_data = data['eng']
tar_data = data['hin']

# %%
def load_data(src, tar):
  xdataset = []
  ydataset = []

  for sent in src:
    sentence = 'SOS ' + sent + ' EOS'
    xdataset.append(sentence)
  
  for sent in tar:
    sentence = 'SOS ' + sent + ' EOS'
    ydataset.append(sentence)

  return xdataset, ydataset

# %%
class Vocabulary:

  def __init__(self, name):
    PAD_token = 0   # Used for padding short sentences
    SOS_token = 1   # Start-of-sentence token
    EOS_token = 2   # End-of-sentence token
    self.name = name
    self.word2index = {"PAD": PAD_token , "SOS": SOS_token, "EOS": EOS_token}
    self.word2count = {"PAD": 0, "SOS": 0, "EOS": 0}
    self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
    self.num_words = 3
    self.num_sentences = 0
    self.longest_sentence = 0

  def tokenize(self, text):
      # obtains tokens with a least 1 alphabet
      pattern = re.compile(r'[A-Za-z]+[\w^\']*|[\w^\']*[A-Za-z]+[\w^\']*')
      return pattern.findall(text.lower())

  def add_word(self, word):
    if word not in self.word2index:
        # First entry of word into vocabulary
        self.word2index[word] = self.num_words
        self.word2count[word] = 1
        self.index2word[self.num_words] = word
        self.num_words += 1
    else:
        # Word exists; increase word count
        self.word2count[word] += 1
        
  def add_sentence(self, sentence):
    sentence_len = 0
    for word in sentence.split(' '):
        sentence_len += 1
        self.add_word(word)
    if sentence_len > self.longest_sentence:
        # This is the longest sentence
        self.longest_sentence = sentence_len
    # Count the number of sentences
    self.num_sentences += 1

  def to_word(self, index):
    return self.index2word[index]

  def to_index(self, word):
    return self.word2index[word]

# %%
xdataset, ydataset  = load_data(src_data, tar_data)

# %%
xdataset[0]
# Out:
# 'SOS Wow! EOS'

# %%
print(len(xdataset))
print(len(ydataset))
# Out:
# 2773
# 2773

# %%
xdataset = xdataset[:1000]
ydataset = ydataset[:1000]

# %%
voc_input = Vocabulary('Input')
for sent in xdataset:
  voc_input.add_sentence(sent)

# %%
voc_output = Vocabulary('Output')
for sent in ydataset:
  voc_output.add_sentence(sent)

# %% [markdown]
# Converting text into matrix form

# %%
xtrain_voc = []
ytrain_voc = []
for sent in xdataset:
  xtemp= []
  for word in sent.split(' '):
    xtemp.append(voc_input.to_index(word))
  xtrain_voc.append(xtemp)

for sent in ydataset:
  ytemp= []
  for word in sent.split(' '):
    ytemp.append(voc_output.to_index(word))
  ytrain_voc.append(ytemp)

print(xtrain_voc)
print(ytrain_voc)
# Out:
# [[1, 3, 2], [1, 4, 2], [1, 5, 2], [1, 5, 2], [1, 5, 2], [1, 6, 2], [1, 6, 2], [1, 7, 2], [1, 7, 2], [1, 8, 9, 2], [1, 10, 11, 2], [1, 12, 2], [1, 13, 14, 2], [1, 15, 16, 2], [1, 17, 18, 2], [1, 19, 2], [1, 20, 2], [1, 20, 2], [1, 21, 2], [1, 21, 2], [1, 22, 23, 2], [1, 22, 23, 2], [1, 22, 23, 2], [1, 24, 25, 2], [1, 24, 25, 2], [1, 26, 27, 2], [1, 10, 28, 2], [1, 10, 29, 2], [1, 30, 31, 2], [1, 32, 33, 2], [1, 34, 35, 2], [1, 36, 33, 2], [1, 37, 2], [1, 24, 38, 2], [1, 24, 39, 40, 2], [1, 24, 41, 2], [1, 10, 42, 2], [1, 10, 43, 2], [1, 10, 44, 2], [1, 45, 46, 2], [1, 47, 48, 2], [1, 49, 50, 2], [1, 49, 50, 2], [1, 49, 50, 2], [1, 49, 50, 2], [1, 51, 2], [1, 34, 52, 2], [1, 13, 53, 14, 2], [1, 54, 2], [1, 55, 56, 2], [1, 57, 58, 2], [1, 59, 60, 2], [1, 24, 61, 62, 2], [1, 24, 61, 62, 2], [1, 24, 63, 64, 2], [1, 24, 63, 64, 2], [1, 24, 63, 64, 2], [1, 24, 63, 64, 2], [1, 24, 63, 64, 2], [1, 24, 65, 66, 2], [1, 10, 67, 2], [1, 10, 68, 2], [1, 10, 68, 2], [1, 69, 70, 14, 2], [1, 69, 70, 14, 2], [1, 69, 71, 16, 2], [1, 72, 73, 2], [1, 74, 75, 2], [1, 76, 77, 78, 2], [1, 79, 80, 2], [1, 79, 80, 2], [1, 81, 82, 2], [1, 55, 83, 2], [1, 55, 83, 2], [1, 84, 85, 86, 2], [1, 87, 88, 2], [1, 89, 90, 91, 2], [1, 89, 90, 91, 2], [1, 89, 90, 91, 2], [1, 89, 90, 91, 2], [1, 89, 90, 91, 2], [1, 89, 90, 91, 2], [1, 89, 90, 91, 2], [1, 24, 92, 93, 2], [1, 24, 92, 94, 2], [1, 24, 92, 95, 2], [1, 24, 92, 96, 2], [1, 26, 97, 2], [1, 98, 99, 2], [1, 100, 24, 101, 2], [1, 79, 102, 2], [1, 103, 104, 105, 2], [1, 106, 70, 14, 2], [1, 13, 107, 108, 2], [1, 109, 110, 2], [1, 111, 112, 113, 2], [1, 24, 114, 115, 116, 2], [1, 24, 117, 56, 2], [1, 24, 118, 119, 2], [1, 24, 118, 119, 2], [1, 24, 120, 77, 121, 2], [1, 24, 120, 77, 122, 2], [1, 24, 123, 2], [1, 10, 77, 124, 2], [1, 125, 126, 77, 127, 2], [1, 45, 128, 2], [1, 45, 129, 130, 2], [1, 74, 131, 2], [1, 132, 2], [1, 133, 90, 134, 2], [1, 135, 126, 102, 2], [1, 103, 104, 136, 2], [1, 137, 104, 138, 2], [1, 55, 139, 140, 2], [1, 55, 141, 14, 2], [1, 142, 143, 144, 2], [1, 145, 146, 2], [1, 147, 148, 2], [1, 24, 114, 149, 24, 150, 2], [1, 26, 151, 60, 2], [1, 10, 152, 153, 2], [1, 10, 154, 155, 2], [1, 156, 157, 77, 158, 2], [1, 45, 159, 160, 2], [1, 45, 159, 160, 2], [1, 69, 71, 161, 162, 2], [1, 69, 71, 161, 162, 2], [1, 69, 71, 161, 162, 2], [1, 163, 143, 164, 2], [1, 165, 24, 166, 167, 2], [1, 168, 169, 170, 2], [1, 168, 169, 170, 2], [1, 74, 139, 14, 2], [1, 171, 143, 73, 2], [1, 171, 143, 172, 2], [1, 173, 174, 144, 2], [1, 175, 176, 35, 2], [1, 177, 126, 77, 178, 2], [1, 112, 126, 179, 180, 2], [1, 181, 182, 183, 2], [1, 184, 104, 185, 2], [1, 135, 186, 187, 2], [1, 137, 24, 188, 91, 2], [1, 137, 24, 188, 91, 2], [1, 189, 169, 190, 2], [1, 55, 191, 162, 2], [1, 15, 192, 193, 194, 2], [1, 109, 195, 196, 2], [1, 109, 195, 196, 2], [1, 109, 197, 2], [1, 84, 198, 77, 199, 2], [1, 84, 126, 200, 201, 2], [1, 84, 202, 203, 2], [1, 84, 204, 205, 86, 2], [1, 24, 92, 206, 2], [1, 24, 92, 169, 122, 2], [1, 24, 207, 208, 209, 2], [1, 26, 166, 210, 2], [1, 26, 211, 64, 2], [1, 26, 212, 116, 2], [1, 10, 200, 213, 2], [1, 10, 200, 213, 2], [1, 10, 154, 44, 2], [1, 45, 214, 215, 2], [1, 45, 216, 127, 2], [1, 45, 217, 56, 2], [1, 218, 219, 220, 2], [1, 221, 126, 222, 2], [1, 223, 217, 224, 2], [1, 225, 186, 162, 2], [1, 177, 126, 77, 127, 2], [1, 177, 126, 77, 127, 2], [1, 177, 126, 179, 226, 2], [1, 177, 126, 179, 122, 2], [1, 227, 217, 228, 2], [1, 133, 229, 230, 2], [1, 231, 232, 64, 2], [1, 231, 232, 64, 2], [1, 233, 234, 91, 2], [1, 233, 234, 91, 2], [1, 235, 120, 236, 237, 2], [1, 235, 238, 44, 2], [1, 239, 240, 2], [1, 241, 242, 207, 243, 2], [1, 103, 104, 115, 244, 2], [1, 103, 104, 245, 246, 2], [1, 13, 247, 248, 2], [1, 13, 249, 104, 250, 2], [1, 251, 2], [1, 251, 2], [1, 252, 253, 254, 255, 2], [1, 252, 104, 256, 257, 2], [1, 55, 258, 259, 2], [1, 84, 260, 261, 2], [1, 84, 117, 258, 262, 2], [1, 84, 198, 77, 263, 264, 2], [1, 84, 265, 266, 2], [1, 87, 179, 267, 2], [1, 89, 126, 268, 2], [1, 89, 126, 143 ...
# [[1, 3, 2], [1, 4, 2], [1, 5, 2], [1, 6, 2], [1, 7, 2], [1, 8, 2], [1, 9, 2], [1, 10, 2], [1, 11, 2], [1, 12, 13, 14, 2], [1, 15, 16, 17, 2], [1, 18, 19, 2], [1, 20, 21, 22, 2], [1, 23, 24, 25, 2], [1, 26, 25, 2], [1, 27, 28, 2], [1, 29, 2], [1, 30, 2], [1, 31, 32, 33, 2], [1, 34, 2], [1, 35, 36, 2], [1, 37, 36, 2], [1, 35, 38, 2], [1, 15, 39, 40, 2], [1, 15, 39, 41, 2], [1, 15, 42, 43, 2], [1, 15, 16, 17, 2], [1, 44, 45, 46, 47, 33, 2], [1, 48, 49, 2], [1, 50, 51, 52, 2], [1, 53, 54, 55, 2], [1, 56, 57, 2], [1, 18, 58, 2], [1, 15, 59, 60, 40, 2], [1, 61, 62, 63, 64, 65, 66, 67, 33, 2], [1, 15, 68, 2], [1, 15, 69, 60, 70, 17, 2], [1, 44, 71, 60, 72, 33, 2], [1, 15, 73, 47, 17, 2], [1, 74, 60, 75, 33, 2], [1, 76, 2], [1, 77, 78, 2], [1, 79, 80, 81, 2], [1, 82, 80, 81, 2], [1, 82, 83, 81, 2], [1, 84, 2], [1, 53, 85, 55, 2], [1, 20, 21, 22, 2], [1, 86, 67, 2], [1, 87, 88, 2], [1, 89, 90, 33, 2], [1, 91, 92, 38, 2], [1, 50, 93, 94, 33, 2], [1, 15, 95, 96, 17, 2], [1, 15, 97, 98, 99, 17, 2], [1, 15, 97, 98, 100, 17, 2], [1, 15, 101, 98, 100, 17, 2], [1, 15, 101, 98, 99, 17, 2], [1, 50, 97, 98, 33, 2], [1, 15, 102, 103, 2], [1, 15, 21, 70, 17, 2], [1, 50, 104, 105, 106, 2], [1, 50, 104, 105, 33, 2], [1, 107, 20, 108, 2], [1, 107, 109, 110, 52, 2], [1, 50, 23, 111, 112, 2], [1, 113, 114, 115, 2], [1, 116, 2], [1, 76, 2], [1, 117, 118, 81, 2], [1, 118, 117, 81, 2], [1, 119, 77, 81, 2], [1, 120, 121, 2], [1, 122, 88, 2], [1, 119, 123, 60, 40, 2], [1, 119, 124, 33, 2], [1, 125, 126, 127, 2], [1, 128, 126, 129, 2], [1, 128, 130, 129, 2], [1, 131, 132, 81, 2], [1, 131, 130, 81, 2], [1, 125, 130, 127, 2], [1, 125, 126, 129, 2], [1, 50, 133, 134, 55, 2], [1, 50, 135, 136, 137, 33, 2], [1, 50, 138, 139, 140, 55, 2], [1, 50, 141, 134, 33, 2], [1, 15, 142, 2], [1, 143, 144, 145, 2], [1, 117, 15, 146, 147, 2], [1, 148, 117, 81, 2], [1, 117, 128, 149, 129, 2], [1, 150, 20, 151, 152, 2], [1, 153, 154, 152, 2], [1, 155, 156, 157, 2], [1, 158, 159, 47, 160, 2], [1, 15, 161, 162, 17, 2], [1, 15, 163, 144, 164, 2], [1, 50, 144, 165, 2], [1, 50, 144, 166, 2], [1, 167, 168, 114, 169, 33, 2], [1, 167, 168, 114, 170, 33, 2], [1, 15, 171, 17, 2], [1, 15, 172, 17, 2], [1, 148, 173, 33, 2], [1, 174, 175, 75, 33, 2], [1, 18, 176, 177, 33, 2], [1, 178, 179, 2], [1, 180, 2], [1, 181, 182, 55, 2], [1, 148, 117, 81, 2], [1, 73, 183, 60, 160, 2], [1, 128, 169, 159, 184, 60, 160, 2], [1, 185, 186, 60, 187, 2], [1, 188, 186, 189, 190, 2], [1, 191, 192, 193, 2], [1, 194, 195, 196, 62, 197, 33, 2], [1, 198, 199, 55, 2], [1, 15, 200, 201, 17, 2], [1, 15, 107, 202, 2], [1, 15, 203, 73, 47, 17, 2], [1, 15, 18, 204, 17, 2], [1, 119, 205, 206, 160, 2], [1, 148, 207, 33, 2], [1, 148, 207, 208, 33, 2], [1, 50, 209, 2], [1, 50, 210, 52, 2], [1, 50, 211, 212, 52, 2], [1, 213, 57, 2], [1, 15, 20, 21, 96, 200, 160, 2], [1, 214, 215, 2], [1, 214, 216, 2], [1, 178, 20, 217, 2], [1, 218, 219, 220, 2], [1, 221, 222, 2], [1, 119, 223, 224, 2], [1, 225, 226, 227, 228, 55, 2], [1, 148, 229, 33, 2], [1, 158, 44, 230, 33, 2], [1, 181, 231, 232, 55, 2], [1, 117, 233, 234, 235, 236, 237, 2], [1, 238, 160, 2], [1, 117, 15, 239, 240, 241, 96, 242, 2], [1, 117, 15, 239, 243, 241, 96, 242, 2], [1, 244, 245, 246, 38, 2], [1, 107, 247, 88, 2], [1, 248, 249, 23, 250, 2], [1, 251, 252, 62, 253, 2], [1, 254, 255, 62, 256, 2], [1, 257, 156, 157, 2], [1, 258, 168, 259, 33, 2], [1, 119, 260, 33, 2], [1, 107, 261, 62, 262, 33, 2], [1, 150, 261, 62, 263, 264, 2], [1, 50, 265, 134, 33, 2], [1, 50, 148, 170, 136, 137, 33, 2], [1, 50, 114, 195, 266, 67, 267, 2], [1, 15, 268, 269, 2], [1, 15, 233, 270, 103, 2], [1, 15, 161, 162, 67, 271, 2], [1, 15, 272, 17, 2], [1, 15, 273, 232, 274, 144, 275, 2], [1, 15, 18, 73, 47, 17, 2], [1, 276, 277, 18, 278, 33, 2], [1, 148, 173, 33, 2], [1, 279, 280, 33, 2], [1, 273, 281, 2], [1, 282, 192, 283, 284, 55, 2], [1, 285, 249, 152, 2], [1, 286, 190, 2], [1, 148, 114, 173, 33, 2], [1, 148, 173, 33, 2], [1, 148, 44, 287, 33, 2], [1, 148, 44, 170, 33, 2], [1, 288, 289, 290, ...

# %% [markdown]
# Padding

# %%
X_temp = np.zeros([len(xtrain_voc),len(max(xtrain_voc,key = lambda x: len(x)))])
for i,j in enumerate(xtrain_voc):
    X_temp[i][0:len(j)] = j

Y_temp = np.zeros([len(ytrain_voc),len(max(ytrain_voc,key = lambda x: len(x)))])
for i,j in enumerate(ytrain_voc):
    Y_temp[i][0:len(j)] = j

X_temp = X_temp.astype(np.int32)
Y_temp = Y_temp.astype(np.int32)

print(X_temp)
print(Y_temp)
# Out:
# [[   1    3    2 ...    0    0    0]
#  [   1    4    2 ...    0    0    0]
#  [   1    5    2 ...    0    0    0]
#  ...
#  [   1 3434  126 ...    0    0    0]
#  [   1 2301  179 ...    0    0    0]
#  [   1  550   24 ...  193  598    2]]
# [[   1    3    2 ...    0    0    0]
#  [   1    4    2 ...    0    0    0]
#  [   1    5    2 ...    0    0    0]
#  ...
#  [   1 3087 2663 ...    0    0    0]
#  [   1 1722   44 ...    0    0    0]
#  [   1 1125   15 ...  241  164    2]]

# %%
print(X_temp.shape,Y_temp.shape)
# Out:
# (2773, 24) (2773, 27)

# %%
input_train, input_test, output_train, output_test = train_test_split(X_temp, Y_temp, test_size=0.2)

# Show length
print(len(input_train), len(output_train), len(input_test), len(output_test))
# Out:
# 2218 2218 555 555

# %%
BUFFER_SIZE = len(input_train)
BATCH_SIZE = 32
steps_per_epoch = len(input_train)//BATCH_SIZE
embedding_dim = 128
units = 256

vocab_inp_size = voc_input.num_words+1
vocab_out_size = voc_output.num_words+1

dataset_train = tf.data.Dataset.from_tensor_slices((input_train, output_train)).shuffle(BUFFER_SIZE)
dataset_train = dataset_train.batch(BATCH_SIZE, drop_remainder=True)

# %%
input_batch, target_batch = next(iter(dataset_train))
input_batch.shape, target_batch.shape
# Out:
# (TensorShape([32, 24]), TensorShape([32, 27]))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')   ##GRU

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # query hidden state shape == (batch_size, hidden size)
    # query_with_time_axis shape == (batch_size, 1, hidden size)
    # values shape == (batch_size, max_len, hidden size)
    # we are doing this to broadcast addition along the time axis to calculate the score
    query_with_time_axis = tf.expand_dims(query, 1)

    # score shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    # the shape of the tensor before applying self.V is (batch_size, max_length, units)
    score = self.V(tf.nn.tanh(
        self.W1(query_with_time_axis) + self.W2(values)))

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

attention_layer = BahdanauAttention(10)

# %%
class DotProdAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(DotProdAttention, self).__init__()

  def call(self, query, values):

    query_with_time_axis = tf.expand_dims(query, 1)

    score = np.dot(query_with_time_axis.transpose(), values)

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

attention_layer = DotProdAttention(10)

# %%
class LuongMultiplicativeAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(LuongMultiplicativeAttention, self).__init__()
    self.W = tf.keras.layers.Dense(units)

  def call(self, query, values):

    query_with_time_axis = tf.expand_dims(query, 1)

    score = query_with_time_axis.transpose() * self.W * values

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

attention_layer = LuongMultiplicativeAttention(10)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')  ##GRU
    self.fc = tf.keras.layers.Dense(vocab_size)

    # used for attention
    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):
    # enc_output shape == (batch_size, max_length, hidden_size)
    context_vector, attention_weights = self.attention(hidden, enc_output)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state, attention_weights

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)
decoder = Decoder(vocab_out_size, embedding_dim, units, BATCH_SIZE)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_hidden = encoder(inp, enc_hidden)
    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([voc_output.word2index['SOS']] * BATCH_SIZE, 1)
    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 100

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset_train.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)
    
  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 2.3723
# Epoch 1 Loss 1.8958
# Time taken for 1 epoch 61.06557559967041 sec
#
# Epoch 2 Batch 0 Loss 1.8383
# Epoch 2 Loss 1.6949
# Time taken for 1 epoch 37.871031761169434 sec
#
# Epoch 3 Batch 0 Loss 1.4792
# Epoch 3 Loss 1.6127
# Time taken for 1 epoch 37.868489503860474 sec
#
# Epoch 4 Batch 0 Loss 1.5345
# Epoch 4 Loss 1.5535
# Time taken for 1 epoch 41.14142107963562 sec
#
# Epoch 5 Batch 0 Loss 1.6234
# Epoch 5 Loss 1.5080
# Time taken for 1 epoch 37.85800647735596 sec
#
# Epoch 6 Batch 0 Loss 1.4226
# Epoch 6 Loss 1.4641
# Time taken for 1 epoch 38.112282514572144 sec
#
# Epoch 7 Batch 0 Loss 1.6131
# Epoch 7 Loss 1.4160
# Time taken for 1 epoch 38.03775906562805 sec
#
# Epoch 8 Batch 0 Loss 1.3791
# Epoch 8 Loss 1.3703
# Time taken for 1 epoch 37.949124813079834 sec
#
# Epoch 9 Batch 0 Loss 1.2106
# Epoch 9 Loss 1.3254
# Time taken for 1 epoch 37.84076738357544 sec
#
# Epoch 10 Batch 0 Loss 1.2126
# Epoch 10 Loss 1.2808
# Time taken for 1 epoch 39.52230715751648 sec
#
# Epoch 11 Batch 0 Loss 1.1855
# Epoch 11 Loss 1.2422
# Time taken for 1 epoch 38.07488179206848 sec
#
# Epoch 12 Batch 0 Loss 1.1719
# Epoch 12 Loss 1.2024
# Time taken for 1 epoch 38.153347969055176 sec
#
# Epoch 13 Batch 0 Loss 1.1907
# Epoch 13 Loss 1.1631
# Time taken for 1 epoch 38.486822843551636 sec
#
# Epoch 14 Batch 0 Loss 1.0017
# Epoch 14 Loss 1.1240
# Time taken for 1 epoch 38.00327920913696 sec
#
# Epoch 15 Batch 0 Loss 1.0445
# Epoch 15 Loss 1.0854
# Time taken for 1 epoch 38.091779947280884 sec
#
# Epoch 16 Batch 0 Loss 0.9901
# Epoch 16 Loss 1.0476
# Time taken for 1 epoch 38.38345456123352 sec
#
# Epoch 17 Batch 0 Loss 0.9859
# Epoch 17 Loss 1.0109
# Time taken for 1 epoch 38.09737253189087 sec
#
# Epoch 18 Batch 0 Loss 0.9686
# Epoch 18 Loss 0.9733
# Time taken for 1 epoch 37.87419891357422 sec
#
# Epoch 19 Batch 0 Loss 0.9413
# Epoch 19 Loss 0.9375
# Time taken for 1 epoch 37.412245988845825 sec
#
# Epoch 20 Batch 0 Loss 0.9502
# Epoch 20 Loss 0.9018
# Time taken for 1 epoch 42.571839809417725 sec
#
# Epoch 21 Batch 0 Loss 0.8675
# Epoch 21 Loss 0.8648
# Time taken for 1 epoch 37.82133221626282 sec
#
# Epoch 22 Batch 0 Loss 0.8404
# Epoch 22 Loss 0.8310
# Time taken for 1 epoch 37.75888013839722 sec
#
# Epoch 23 Batch 0 Loss 0.8957
# Epoch 23 Loss 0.7990
# Time taken for 1 epoch 38.267234325408936 sec
#
# Epoch 24 Batch 0 Loss 0.7176
# Epoch 24 Loss 0.7679
# Time taken for 1 epoch 38.57723784446716 sec
#
# Epoch 25 Batch 0 Loss 0.6970
# Epoch 25 Loss 0.7360
# Time taken for 1 epoch 37.57549428939819 sec
#
# Epoch 26 Batch 0 Loss 0.7656
# Epoch 26 Loss 0.7038
# Time taken for 1 epoch 38.23596549034119 sec
#
# Epoch 27 Batch 0 Loss 0.6531
# Epoch 27 Loss 0.6754
# Time taken for 1 epoch 37.9465446472168 sec
#
# Epoch 28 Batch 0 Loss 0.6017
# Epoch 28 Loss 0.6470
# Time taken for 1 epoch 37.93584656715393 sec
#
# Epoch 29 Batch 0 Loss 0.5382
# Epoch 29 Loss 0.6181
# Time taken for 1 epoch 37.85100555419922 sec
#
# Epoch 30 Batch 0 Loss 0.5423
# Epoch 30 Loss 0.5897
# Time taken for 1 epoch 37.435152769088745 sec
#
# Epoch 31 Batch 0 Loss 0.5307
# Epoch 31 Loss 0.5627
# Time taken for 1 epoch 37.41589403152466 sec
#
# Epoch 32 Batch 0 Loss 0.5015
# Epoch 32 Loss 0.5366
# Time taken for 1 epoch 37.28799653053284 sec
#
# Epoch 33 Batch 0 Loss 0.5040
# Epoch 33 Loss 0.5107
# Time taken for 1 epoch 37.62999892234802 sec
#
# Epoch 34 Batch 0 Loss 0.5562
# Epoch 34 Loss 0.4868
# Time taken for 1 epoch 37.58054256439209 sec
#
# Epoch 35 Batch 0 Loss 0.3453
# Epoch 35 Loss 0.4662
# Time taken for 1 epoch 38.29462146759033 sec
#
# Epoch 36 Batch 0 Loss 0.4139
# Epoch 36 Loss 0.4435
# Time taken for 1 epoch 41.323850870132446 sec
#
# Epoch 37 Batch 0 Loss 0.3752
# Epoch 37 Loss 0.4201
# Time taken for 1 epoch 39.59372282028198 sec
#
# Epoch 38 Batch 0 Loss 0.3326
# Epoch 38 Loss 0.3981
# Time taken for 1 epoch 38.70579385757446 sec
#
# Epoch 39 Batch 0 Loss 0.4107
# Epoch 39 Loss 0.3794
# Time taken for 1 epoch 39.37678599357605 sec
#
# Epoch 40 Batch 0 Loss 0.3492
# Epoch 40 Loss 0.3608
# Time taken for 1 epoch 39.64285087585449 sec
#
# Epoch 41 Batch 0 Loss 0.3449
# Epoch 41 Loss 0.3437
# Time taken for 1 epoch 39.81498408317566 sec
#
# Epoch 42 Batch 0 Loss 0.3298
# Epoch 42 Loss 0.3254
# Time taken for 1 epoch 39.22231101989746 sec
#
# Epoch 43 Batch 0 Loss 0.2916
# Epoch 43 Loss 0.3076
# Time taken for 1 epoch 38.6798050403595 sec
#
# Epoch 44 Batch 0 Loss 0.2395
# Epoch 44 Loss 0.2915
# Time taken for 1 epoch 39.06588935852051 sec
#
# Epoch 45 Batch 0 Loss 0.2924
# Epoch 45 Loss 0.2777
# Time taken for 1 epoch 38.779826641082764 sec
#
# Epoch 46 Batch 0 Loss 0.2413
# Epoch 46 Loss 0.2614
# Time taken for 1 epoch 38.636953592300415 sec
#
# Epoch 47 Batch 0 Loss 0.2093
# Epoch 47 Loss 0.2467
# Time taken for 1 epoch 38.7869393825531 sec
#
# Epoch 48 Batch 0 Loss 0.2136
# Epoch 48 Loss 0.2338
# Time taken for 1 epoch 38.95080828666687 sec
#
# Epoch 49 Batch 0 Loss 0.1932
# Epoch 49 Loss 0.2199
# Time taken for 1 epoch 38.52614998817444 sec
#
# Epoch 50 Batch 0 Loss 0.1997
# Epoch 50 Loss 0.2068
# Time taken for 1 epoch 38.3647997379303 sec
#
# Epoch 51 Batch 0 Loss 0.1960
# Epoch 51 Loss 0.1953
# Time taken for 1 epoch 41.61575937271118 sec
#
# Epoch 52 Batch 0 Loss 0.1935
# Epoch 52 Loss 0.1843
# Time taken for 1 epoch 39.025463342666626 sec
#
# Epoch 53 Batch 0 Loss 0.1525
# Epoch 53 Loss 0.1734
# Time taken for 1 epoch 38.433767795562744 sec
#
# Epoch 54 Batch 0 Loss 0.1678
# Epoch 54 Loss 0.1648
# Time taken for 1 epoch 38.60607028007507 sec
#
# Epoch 55 Batch 0 Loss 0.1538
# Epoch 55 Loss 0.1559
# Time taken for 1 epoch 38.335160970687866 sec
#
# Epoch 56 Batch 0 Loss 0.1228
# Epoch 56 Loss 0.1470
# Time taken for 1 epoch 38.244574546813965 sec
#
# Epoch 57 Batch 0 Loss 0.1268
# Epoch 57 Loss 0.1386
# Time taken for 1 epoch 38.87142848968506 sec
#
# Epoch 58 Batch 0 Loss 0.1240
# Epoch 58 Loss 0.1294
# Time taken for 1 epoch 38.21332788467407 sec
#
# Epoch 59 Batch 0 Loss 0.1091
# Epoch 59 Loss 0.1210
# Time taken for 1 epoch 37.84214448928833 sec
#
# Epoch 60 Batch 0 Loss 0.0925
# Epoch 60 Loss 0.1139
# Time taken for 1 epoch 38.07299733161926 sec
#
# Epoch 61 Batch 0 Loss 0.0806
# Epoch 61 Loss 0.1069
# Time taken for 1 epoch 37.97300863265991 sec
#
# Epoch 62 Batch 0 Loss 0.0958
# Epoch 62 Loss 0.1000
# Time taken for 1 epoch 38.22401404380798 sec
#
# Epoch 63 Batch 0 Loss 0.1109
# Epoch 63 Loss 0.0941
# Time taken for 1 epoch 38.04243230819702 sec
#
# Epoch 64 Batch 0 Loss 0.0872
# Epoch 64 Loss 0.0879
# Time taken for 1 epoch 37.86253070831299 sec
#
# Epoch 65 Batch 0 Loss 0.0798
# Epoch 65 Loss 0.0830
# Time taken for 1 epoch 38.45415735244751 sec
#
# Epoch 66 Batch 0 Loss 0.0739
# Epoch 66 Loss 0.0798
# Time taken for 1 epoch 38.71881914138794 sec
#
# Epoch 67 Batch 0 Loss 0.0611
# Epoch 67 Loss 0.0763
# Time taken for 1 epoch 41.54937410354614 sec
#
# Epoch 68 Batch 0 Loss 0.0579
# Epoch 68 Loss 0.0709
# Time taken for 1 epoch 38.60010027885437 sec
#
# Epoch 69 Batch 0 Loss 0.0573
# Epoch 69 Loss 0.0665
# Time taken for 1 epoch 38.574156045913696 sec
#
# Epoch 70 Batch 0 Loss 0.0572
# Epoch 70 Loss 0.0612
# Time taken for 1 epoch 38.78003644943237 sec
#
# Epoch 71 Batch 0 Loss 0.0538
# Epoch 71 Loss 0.0568
# Time taken for 1 epoch 38.75884389877319 sec
#
# Epoch 72 Batch 0 Loss 0.0427
# Epoch 72 Loss 0.0532
# Time taken for 1 epoch 38.698047161102295 sec
#
# Epoch 73 Batch 0 Loss 0.0479
# Epoch 73 Loss 0.0497
# Time taken for 1 epoch 39.22250723838806 sec
#
# Epoch 74 Batch 0 Loss 0.0389
# Epoch 74 Loss 0.0478
# Time taken for 1 epoch 38.36726927757263 sec
#
# Epoch 75 Batch 0 Loss 0.0434
# Epoch 75 Loss 0.0456
# Time taken for 1 epoch 38.21927237510681 sec
#
# Epoch 76 Batch 0 Loss 0.0428
# Epoch 76 Loss 0.0434
# Time taken for 1 epoch 37.683269023895264 sec
#
# Epoch 77 Batch 0 Loss 0.0412
# Epoch 77 Loss 0.0403
# Time taken for 1 epoch 38.12074160575867 sec
#
# Epoch 78 Batch 0 Loss 0.0275
# Epoch 78 Loss 0.0389
# Time taken for 1 epoch 37.81402897834778 sec
#
# Epoch 79 Batch 0 Loss 0.0378
# Epoch 79 Loss 0.0383
# Time taken for 1 epoch 37.95692801475525 sec
#
# Epoch 80 Batch 0 Loss 0.0334
# Epoch 80 Loss 0.0356
# Time taken for 1 epoch 37.59637451171875 sec
#
# Epoch 81 Batch 0 Loss 0.0327
# Epoch 81 Loss 0.0333
# Time taken for 1 epoch 38.38268232345581 sec
#
# Epoch 82 Batch 0 Loss 0.0372
# Epoch 82 Loss 0.0312
# Time taken for 1 epoch 37.90968608856201 sec
#
# Epoch 83 Batch 0 Loss 0.0275
# Epoch 83 Loss 0.0292
# Time taken for 1 epoch 40.801422357559204 sec
#
# Epoch 84 Batch 0 Loss 0.0235
# Epoch 84 Loss 0.0275
# Time taken for 1 epoch 37.71739435195923 sec
#
# Epoch 85 Batch 0 Loss 0.0200
# Epoch 85 Loss 0.0261
# Time taken for 1 epoch 38.17642116546631 sec
#
# Epoch 86 Batch 0 Loss 0.0218
# Epoch 86 Loss 0.0255
# Time taken for 1 epoch 38.67657923698425 sec
#
# Epoch 87 Batch 0 Loss 0.0294
# Epoch 87 Loss 0.0269
# Time taken for 1 epoch 38.06205892562866 sec
#
# Epoch 88 Batch 0 Loss 0.0309
# Epoch 88 Loss 0.0358
# Time taken for 1 epoch 38.1990487575531 sec
#
# Epoch 89 Batch 0 Loss 0.0400
# Epoch 89 Loss 0.0567
# Time taken for 1 epoch 38.48052477836609 sec
#
# Epoch 90 Batch 0 Loss 0.0510
# Epoch 90 Loss 0.0705
# Time taken for 1 epoch 37.53338694572449 sec
#
# Epoch 91 Batch 0 Loss 0.0468
# Epoch 91 Loss 0.0592
# Time taken for 1 epoch 37.824366331100464 sec
#
# Epoch 92 Batch 0 Loss 0.0396
# Epoch 92 Loss 0.0398
# Time taken for 1 epoch 37.77984881401062 sec
#
# Epoch 93 Batch 0 Loss 0.0286
# Epoch 93 Loss 0.0272
# Time taken for 1 epoch 38.64974308013916 sec
#
# Epoch 94 Batch 0 Loss 0.0190
# Epoch 94 Loss 0.0211
# Time taken for 1 epoch 40.4865083694458 sec
#
# Epoch 95 Batch 0 Loss 0.0170
# Epoch 95 Loss 0.0185
# Time taken for 1 epoch 41.077027797698975 sec
#
# Epoch 96 Batch 0 Loss 0.0179
# Epoch 96 Loss 0.0171
# Time taken for 1 epoch 39.86381196975708 sec
#
# Epoch 97 Batch 0 Loss 0.0180
# Epoch 97 Loss 0.0163
# Time taken for 1 epoch 39.82686424255371 sec
#
# Epoch 98 Batch 0 Loss 0.0117
# Epoch 98 Loss 0.0156
# Time taken for 1 epoch 39.70985460281372 sec
#
# Epoch 99 Batch 0 Loss 0.0209
# Epoch 99 Loss 0.0151
# Time taken for 1 epoch 41.20180535316467 sec
#
# Epoch 100 Batch 0 Loss 0.0118
# Epoch 100 Loss 0.0146
# Time taken for 1 epoch 38.73622155189514 sec

# %%
max_length_targ, max_length_inp = Y_temp.shape[1], X_temp.shape[1]

# %%
voc_output.index2word
# Out:
# {0: 'PAD',
#  1: 'SOS',
#  2: 'EOS',
#  3: 'वाह!',
#  4: 'बचाओ!',
#  5: 'उछलो.',
#  6: 'कूदो.',
#  7: 'छलांग.',
#  8: 'नमस्ते।',
#  9: 'नमस्कार।',
#  10: 'वाह-वाह!',
#  11: 'चियर्स!',
#  12: 'समझे',
#  13: 'कि',
#  14: 'नहीं?',
#  15: 'मैं',
#  16: 'ठीक',
#  17: 'हूँ।',
#  18: 'बहुत',
#  19: 'बढ़िया!',
#  20: 'अंदर',
#  21: 'आ',
#  22: 'जाओ।',
#  23: 'बाहर',
#  24: 'निकल',
#  25: 'जाओ!',
#  26: 'चले',
#  27: 'ख़ुदा',
#  28: 'हाफ़िज़।',
#  29: 'उत्तम!',
#  30: 'सही!',
#  31: 'आपका',
#  32: 'स्वागत',
#  33: 'है।',
#  34: 'स्वागतम्।',
#  35: 'मज़े',
#  36: 'करना।',
#  37: 'मौज',
#  38: 'करो।',
#  39: 'भूल',
#  40: 'गया।',
#  41: 'गई।',
#  42: 'पैसे',
#  43: 'दूंगा।',
#  44: 'मेरा',
#  45: 'पेट',
#  46: 'भर',
#  47: 'गया',
#  48: 'चलो',
#  49: 'चलें!',
#  50: 'मुझे',
#  51: 'जवाब',
#  52: 'दो।',
#  53: 'पंछी',
#  54: 'उड़ते',
#  55: 'हैं।',
#  56: 'माफ़',
#  57: 'कीजिए।',
#  58: 'ख़ूब!',
#  59: 'बेहोश',
#  60: 'हो',
#  61: 'खेद',
#  62: 'की',
#  63: 'बात',
#  64: 'है,',
#  65: 'लेकिन',
#  66: 'वैसा',
#  67: 'ही',
#  68: 'हँसा।',
#  69: 'बोर',
#  70: 'रहा',
#  71: 'दीवालिया',
#  72: 'चुका',
#  73: 'थक',
#  74: 'ठंड',
#  75: 'रही',
#  76: 'शाबाश!',
#  77: 'कौन',
#  78: 'जाने?',
#  79: 'किसको',
#  80: 'पता',
#  81: 'है?',
#  82: 'किसे',
#  83: 'मालूम',
#  84: 'अद्भुत',
#  85: 'गाते',
#  86: 'निश्चित',
#  87: 'हिलो',
#  88: 'मत।',
#  89: 'आग',
#  90: 'जलाती',
#  91: 'उसका',
#  92: 'पीछा',
#  93: 'तैरना',
#  94: 'आता',
#  95: 'तैर',
#  96: 'सकता',
#  97: 'तुमसे',
#  98: 'प्यार',
#  99: 'करती',
#  100: 'करता',
#  101: 'आपसे',
#  102: 'कोशिश',
#  103: 'करूँगा।',
#  104: 'भूख',
#  105: 'लगी',
#  106: 'है!',
#  107: 'उसे',
#  108: 'भेजो।',
#  109: 'अंगर',
#  110: 'आने',
#  111: 'जाने',
#  112: 'दो!',
#  113: 'और',
#  114: 'एक',
#  115: 'बार।',
#  116: 'बैठिए।',
#  117: 'क्या',
#  118: 'नया',
#  119: 'वह',
#  120: 'चिल्लाओ',
#  121: 'मत!',
#  122: 'चिल्लाईए',
#  123: 'खड़ा',
#  124: 'ताकतवर',
#  125: 'आप',
#  126: 'कैसे',
#  127: 'हैं?',
#  128: 'तुम',
#  129: 'हो?',
#  130: 'कैसी',
#  131: 'तू',
#  132: 'कैसा',
#  133: 'दोनो',
#  134: 'पसंद',
#  135: 'केक',
#  136: 'अच्छा',
#  137: 'लगता',
#  138: 'कुत्ते',
#  139: 'अच्छे',
#  140: 'लगते',
#  141: 'गणित',
#  142: 'आऊंगा।',
#  143: 'कोई',
#  144: 'नहीं',
#  145: 'आया।',
#  146: 'ग़लत',
#  147: 'था?',
#  148: 'यह',
#  149: 'बीमार',
#  150: 'उसको',
#  151: 'ले',
#  152: 'आओ।',
#  153: 'हमारे',
#  154: 'साथ',
#  155: 'एसटर',
#  156: 'मुबारक',
#  157: 'हो!',
#  158: 'टॉम',
#  159: 'चला',
#  160: 'क्या?',
#  161: 'घर',
#  162: 'पर',
#  163: 'हिल',
#  164: 'सकता।',
#  165: 'पता।',
#  166: 'मालूम।',
#  167: 'मेरे',
#  168: 'पास',
#  169: 'गाड़ी',
#  170: 'कुत्ता',
#  171: 'समझता',
#  172: 'डॉक्टर',
#  173: 'किताब',
#  174: 'बरफ़',
#  175: 'गिर',
#  176: 'ज़्यादा',
#  177: 'बड़ा',
#  178: 'कृपया',
#  179: 'जाईये।',
#  180: 'अविश्वसनीय!',
#  181: 'हम',
#  182: 'खुश',
#  183: 'गए',
#  184: 'सकते',
#  185: 'मोटे',
#  186: 'मत',
#  187: 'जाना।',
#  188: 'हार',
#  189: 'मान',
#  190: 'लो।',
#  191: 'पीकर',
#  192: 'खतम',
#  193: 'करदो।',
#  194: 'मौत',
#  195: 'तो',
#  196: 'सभी',
#  197: 'होती',
#  198: 'फूल',
#  199: 'खिलते',
#  200: 'हूँ',
#  201: 'जो',
#  202: 'लेलूँगा।',
#  203: 'अब',
#  204: 'व्यस्थ',
#  205: 'बिल्ली',
#  206: 'है',
#  207: 'मुफ़्त',
#  208: 'का',
#  209: 'दिखाओ।',
#  210: 'देखने',
#  211: 'ट्राए',
#  212: 'करने',
#  213: 'जल्दी',
#  214: 'दरवाज़ा',
#  215: 'खोलो।',
#  216: 'खोलिए।',
#  217: 'आईए।',
#  218: 'इसे',
#  219: 'दोबारा',
#  220: 'पढ़ें।',
#  221: 'पढ़के',
#  222: 'सुनाओ।',
#  223: 'नीचे',
#  224: 'झुकी।',
#  225: 'कुछ',
#  226: 'मछलियाँ',
#  227: 'उड़',
#  228: 'सकतीं',
#  229: 'नक्शा',
#  230: 'लड़का',
#  231: 'शहर',
#  232: 'में',
#  233: 'तुम्हें',
#  234: 'गोली',
#  235: 'लग',
#  236: 'गई',
#  237: 'थी?',
#  238: 'हमारा',
#  239: 'आपकी',
#  240: 'सहायता',
#  241: 'कर',
#  242: 'हूँ?',
#  243: 'मदद',
#  244: 'कमरे',
#  245: 'को',
#  246: 'साफ़',
#  247: 'छूना',
#  248: 'बिस्तर',
#  249: 'से',
#  250: 'निकलो!',
#  251: 'नव',
#  252: 'वर्ष',
#  253: 'शुभकामनाएं!',
#  254: 'नए',
#  255: 'साल',
#  256: 'बधाईयाँ।',
#  257: 'जन्मदिन',
#  258: 'उसके',
#  259: 'दाढ़ी',
#  260: 'अभिनेता',
#  261: 'पैसों',
#  262: 'ज़रूरत',
#  263: 'कमी',
#  264: 'थी।',
#  265: 'इतिहास',
#  266: 'खरीदना',
#  267: 'होगा।',
#  268: 'वापस',
#  269: 'आऊँगा।',
#  270: 'फ़ोन',
#  271: 'रहूँगा।',
#  272: 'अनीश्वरवादी',
#  273: 'भगवान',
#  274: 'यकीन',
#  275: 'करता।',
#  276: 'आज',
#  277: 'मौसम',
#  278: 'गरम',
#  279: 'तुम्हारी',
#  280: 'चाल',
#  281: 'जाने।',
#  282: 'गर्मियाँ',
#  283: 'हों',
#  284: 'चुकीं',
#  285: 'आराम',
#  286: 'सोच',
#  287: 'बस्ता',
#  288: 'अपने',
#  289: 'पैर',
#  290: 'धोओ।',
#  291: 'संगीत',
#  292: 'पढ़ाई',
#  293: 'करते',
#  294: 'आपको',
#  295: 'करेंगे।',
#  296: 'बुलाएँगे।',
#  297: 'कहाँ',
#  298: 'थे?',
#  299: 'जाना',
#  300: 'थके-हारे',
#  301: 'हो।',
#  302: 'मज़ाक',
#  303: 'रहे',
#  304: 'आदमी',
#  305: 'के',
#  306: 'लिए',
#  307: 'काम',
#  308: 'करना',
#  309: 'ज़रूरी',
#  310: 'पे',
#  311: 'लोग',
#  312: 'आजाओ।',
#  313: 'सको',
#  314: 'आना।',
#  315: 'बधाई',
#  316: 'वहाँ',
#  317: 'मेरी',
#  318: 'याद',
#  319: 'आई',
#  320: 'पागल',
#  321: 'बनो।',
#  322: 'भागते',
#  323: 'हुए',
#  324: 'उसने',
#  325: 'टोपी',
#  326: 'पहनी',
#  327: 'हुई',
#  328: 'अरबी',
#  329: 'पढ़',
#  330: 'पति',
#  331: 'सब',
#  332: 'चल',
#  333: 'कितने',
#  334: 'बदतमीज़',
#  335: 'तुम!',
#  336: 'बदतमीज़!',
#  337: 'मैंने',
#  338: 'रात',
#  339: 'खाना',
#  340: 'पकाया।',
#  341: 'उल्टी',
#  342: 'हर',
#  343: 'जाता',
#  344: 'आवाज़',
#  345: 'सुनाई',
#  346: 'दी।',
#  347: 'वाला',
#  348: 'रोज़',
#  349: 'दौड़ने',
#  350: 'फिरसे',
#  351: 'देखा।',
#  352: 'गिटार',
#  353: 'चाहिए।',
#  354: 'मुझपर',
#  355: 'हमला',
#  356: 'किया',
#  357: 'रसोइया',
#  358: 'बावर्ची',
#  359: 'नसीब',
#  360: 'काला',
#  361: 'यहाँ',
#  362: 'कैफ़े',
#  363: 'पतंग',
#  364: 'उड़ाएँ!',
#  365: 'नहीं,',
#  366: 'था।',
#  367: 'आसपास',
#  368: 'बस',
#  369: 'रोना',
#  370: 'बंद',
#  371: 'अपना',
#  372: 'मूँह',
#  373: 'खोलो!',
#  374: 'हसीना',
#  375: 'बोलती',
#  376: 'बक-बक',
#  377: 'गलती',
#  378: 'बिजली',
#  379: 'ये',
#  380: 'चिड़ियाँ',
#  381: 'तुम्हारे',
#  382: 'हमे',
#  383: 'किसी',
#  384: 'भी',
#  385: 'चीज़',
#  386: 'अभी',
#  387: 'बजे',
#  388: 'समय',
#  389: 'तुमने',
#  390: 'डरा',
#  391: 'दिया!',
#  392: 'इनसान',
#  393: 'हैं',
#  394: 'सिखा',
#  395: 'ऊपर',
#  396: 'तक',
#  397: 'चढ़',
#  398: 'आओ',
#  399: 'बैठो।',
#  400: 'आलूओं',
#  401: 'काटो।',
#  402: 'चावल',
#  403: 'बनाओ।',
#  404: 'शोर',
#  405: 'मचाओ।',
#  406: 'लम्बे',
#  407: 'दोस्त',
#  408: 'संत्रे',
#  409: 'नारंगी',
#  410: 'बोलता',
#  411: 'लो,',
#  412: 'तुम्हारा',
#  413: 'बस्ता।',
#  414: 'नहीं।',
#  415: 'जानता।',
#  416: 'मुश्किल',
#  417: 'आस-पड़ोस',
#  418: 'रहता',
#  419: 'अपनी',
#  420: 'माँ',
#  421: 'प्यास',
#  422: 'अप्रैल',
#  423: 'बारी',
#  424: 'मै',
#  425: 'फिर',
#  426: 'मिलकर',
#  427: 'खुशी',
#  428: 'हुई।',
#  429: 'हस्ताक्षर',
#  430: 'धोखा',
#  431: 'दिया।',
#  432: 'तैयार',
#  433: 'चाबी',
#  434: 'सही',
#  435: 'जा',
#  436: 'रहें',
#  437: 'उम्र',
#  438: 'कौनसी',
#  439: 'चिड़िया',
#  440: 'कहानी',
#  441: 'नाम',
#  442: 'शराबख़ाना',
#  443: 'किसकी',
#  444: 'शायद',
#  445: 'आँखे',
#  446: 'खराब',
#  447: 'पक्षी',
#  448: 'घोसले',
#  449: 'बनातें',
#  450: 'बनातीं',
#  451: 'लड़के',
#  452: 'रहेंगे।',
#  453: 'थें',
#  454: 'थे',
#  455: 'था',
#  456: 'तुम्हे',
#  457: 'धोका',
#  458: 'चिल्लाने',
#  459: 'लगा।',
#  460: 'मुझसे',
#  461: 'मिलने',
#  462: 'आया',
#  463: 'नौकरानी',
#  464: 'रखता',
#  465: 'नौकरी',
#  466: 'पीछे',
#  467: 'पड़ा',
#  468: 'विदेश',
#  469: 'करी',
#  470: 'देशद्रोही',
#  471: 'बन',
#  472: 'जाचुका',
#  473: 'पूरी',
#  474: 'रोई।',
#  475: 'नींद',
#  476: 'सिर',
#  477: 'दर्द',
#  478: 'सिरदर्द',
#  479: 'उससे',
#  480: 'मुलाकात',
#  481: 'सुनता',
#  482: 'दौड़ते',
#  483: 'सच्चा',
#  484: 'बैंक',
#  485: 'विद्यार्थी',
#  486: 'ग़लती',
#  487: 'शुरू',
#  488: 'चोरी',
#  489: 'आँखें',
#  490: 'गईं',
#  491: 'हाथ',
#  492: 'करो!',
#  493: 'गाने',
#  494: 'लगी।',
#  495: 'उसकी',
#  496: 'नीली',
#  497: 'शादीशुदा',
#  498: 'सच्चाई',
#  499: 'बताओ।',
#  500: 'पृथ्वी',
#  501: 'घूमती',
#  502: 'बार',
#  503: 'प्रयत्न',
#  504: 'रेडियो',
#  505: 'चालू',
#  506: 'जानते',
#  507: 'खुशखबर',
#  508: 'जंग',
#  509: 'ख़िलाफ़',
#  510: 'युद्ध',
#  511: 'विरोध',
#  512: 'सुख',
#  513: 'होता',
#  514: 'रहते',
#  515: 'रहती',
#  516: 'समुद्र',
#  517: 'तट',
#  518: 'कहां',
#  519: 'पाय',
#  520: 'किसने',
#  521: 'बनाई',
#  522: 'हाँ।',
#  523: 'बिज़ी',
#  524: 'सोये',
#  525: 'उम्मीद',
#  526: 'छोड़ो।',
#  527: 'पत्थर',
#  528: 'फेंको।',
#  529: 'तेरी',
#  530: 'अकल',
#  531: 'घास',
#  532: 'चरने',
#  533: 'गहरी',
#  534: 'साँस',
#  535: 'ली।',
#  536: 'करीं।',
#  537: 'रोया',
#  538: 'रोया।',
#  539: 'साधा',
#  540: 'ज़रूर',
#  541: 'आएगा।',
#  542: 'चचेरा',
#  543: 'भाई',
#  544: 'ममेरा',
#  545: 'इंतेज़ार',
#  546: 'किया।',
#  547: 'मानता',
#  548: 'अंग्रेज़ी',
#  549: 'सकती',
#  550: 'विश्वास',
#  551: 'होता!',
#  552: 'सुनी।',
#  553: 'उन',
#  554: 'औरतों',
#  555: 'जानता',
#  556: 'पिताजी',
#  557: 'सा',
#  558: '१९६०',
#  559: 'पैदा',
#  560: 'हुआ',
#  561: '१९७९',
#  562: 'टीवी',
#  563: 'देखता',
#  564: 'रातभर',
#  565: 'बाद',
#  566: 'मिलेंगे।',
#  567: 'जितना',
#  568: 'लम्बा',
#  569: 'जैसा',
#  570: 'दिखता',
#  571: 'गिरनी',
#  572: 'गो',
#  573: 'वो',
#  574: 'मजेदार',
#  575: 'I',
#  576: 'महंगा',
#  577: 'महंगी',
#  578: 'संभालने',
#  579: 'रेलगाड़ी',
#  580: 'चलते',
#  581: 'टोयोटा',
#  582: 'परिवार',
#  583: 'छोटा',
#  584: 'सुंदर',
#  585: 'उछल',
#  586: 'पड़ी।',
#  587: 'मुस्कुराया।',
#  588: 'उस',
#  589: 'चिढ़',
#  590: 'आती',
#  591: 'बॅटर',
#  592: 'आऊट',
#  593: 'कौआ',
#  594: 'चली',
#  595: 'बड़े',
#  596: 'सच्ची',
#  597: 'थी',
#  598: 'स्केटिंग',
#  599: 'करके',
#  600: 'मज़ा',
#  601: 'थे।',
#  602: 'चुके',
#  603: 'कितना',
#  604: 'कद्दू',
#  605: 'कब',
#  606: 'बच्चे',
#  607: 'गए?',
#  608: 'कौनसा',
#  609: 'गुलदान',
#  610: 'तोड़',
#  611: 'दिया?',
#  612: 'बनाया',
#  613: 'कलम',
#  614: 'इस्तेमाल',
#  615: 'सवालों',
#  616: 'वे',
#  617: 'जिमखाने',
#  618: 'चलाना',
#  619: 'कीजिएगा,',
#  620: 'खो',
#  621: 'टेक्सी',
#  622: 'बुलवाई।',
#  623: 'अकेलापन',
#  624: 'महसूस',
#  625: 'हुआ।',
#  626: 'पड़ोस',
#  627: 'थका-हारा',
#  628: 'दिखने',
#  629: 'अमीर',
#  630: 'जल्द',
#  631: 'जाएगा।',
#  632: 'हालत',
#  633: 'बुरी',
#  634: 'स्वाद',
#  635: 'बनाया?',
#  636: 'भारत',
#  637: 'पुरानी',
#  638: 'खरीदी।',
#  639: 'गाता',
#  640: 'समझा',
#  641: 'गर्मी',
#  642: 'पूछना',
#  643: 'जोखिम',
#  644: 'लेना',
#  645: 'खाया',
#  646: 'बताने',
#  647: 'शादी',
#  648: 'चाहता',
#  649: 'जीत',
#  650: 'जाए।',
#  651: 'देखना',
#  652: 'चाहूँगा।',
#  653: 'मिलना',
#  654: 'दस',
#  655: 'शराब',
#  656: 'लाता',
#  657: 'लाऊँगा।',
#  658: 'लिया',
#  659: 'टिकट',
#  660: 'बेसबॉल',
#  661: 'खेलतें',
#  662: 'स्याही',
#  663: 'लिखना',
#  664: 'होगा?',
#  665: 'गए।',
#  666: 'बहन',
#  667: 'रही।',
#  668: 'कमीज़',
#  669: 'खींची।',
#  670: 'बाघ',
#  671: 'आसमान',
#  672: 'पेड़',
#  673: 'हरे',
#  674: 'हमारी',
#  675: 'किताबें',
#  676: 'वही',
#  677: 'जिसकी',
#  678: 'ज़बान',
#  679: 'सम्भाल',
#  680: 'हमें',
#  681: 'टैक्स',
#  682: 'भरना',
#  683: 'पड़ेगा।',
#  684: 'इस',
#  685: 'डब्बे',
#  686: 'हवाई',
#  687: 'अड्डा',
#  688: 'टीचर',
#  689: 'क्यों',
#  690: 'आए?',
#  691: 'आओगे',
#  692: 'सर्दी',
#  693: 'क्षमा',
#  694: 'मन',
#  695: 'लगाकर',
#  696: 'पढ़ना',
#  697: 'जान',
#  698: 'बचाली।',
#  699: 'बताया',
#  700: 'पेनसिल',
#  701: 'चिंता',
#  702: 'समुंदर',
#  703: 'रहतीं',
#  704: 'कामयाबी',
#  705: 'जलन',
#  706: 'गुस्सा',
#  707: 'नाराज़',
#  708: 'दो',
#  709: 'उधार',
#  710: 'दीं।',
#  711: 'बहाना',
#  712: 'बना',
#  713: 'लिया।',
#  714: 'की।',
#  715: 'लड़की',
#  716: 'कामयाब',
#  717: 'होना',
#  718: 'योजना',
#  719: 'सहमत',
#  720: 'अजनबी',
#  721: 'तुमपर',
#  722: 'भरोसा',
#  723: 'सेव',
#  724: 'खा',
#  725: '।',
#  726: 'प्रतीक्षा',
#  727: 'आपत्ती',
#  728: 'पीठ',
#  729: 'तकलीफ',
#  730: 'ज़ुकाम',
#  731: 'ऊँगली',
#  732: 'काट',
#  733: 'बेहोशी',
#  734: 'तौर',
#  735: 'कहा',
#  736: 'समझकर',
#  737: 'बोला',
#  738: 'कल',
#  739: 'मिला',
#  740: 'ख़याल',
#  741: 'कभी',
#  742: 'मछली',
#  743: 'एलर्जी',
#  744: 'चश्मा',
#  745: 'चश्मे',
#  746: 'फ़ैसला',
#  747: 'रविवार',
#  748: 'खुला',
#  749: 'बज',
#  750: 'ग्यारह',
#  751: 'आसान',
#  752: 'लेजाने',
#  753: 'लिंकन',
#  754: '१८६५',
#  755: 'दरवाज़े',
#  756: 'दीजिए।',
#  757: 'घड़ी',
#  758: 'लाल',
#  759: 'रंग',
#  760: 'कपड़े',
#  761: 'पहने',
#  762: 'ड्रेस',
#  763: 'ख़ासियत',
#  764: 'भूत',
#  765: 'लिपटा',
#  766: 'ने',
#  767: 'ओर',
#  768: 'चादरें',
#  769: 'गीलीं',
#  770: 'लगतीं',
#  771: 'पानी',
#  772: 'पाइप',
#  773: 'फट',
#  774: 'मेरीं',
#  775: 'जूते',
#  776: 'ज़ू',
#  777: 'रेशम',
#  778: 'टूटी',
#  779: 'तेज़ी',
#  780: 'बीतता',
#  781: 'वार',
#  782: 'इसमें',
#  783: 'लौट',
#  784: 'आओगे?',
#  785: 'पिता',
#  786: 'जाओगे',
#  787: 'साबित',
#  788: 'सकते।',
#  789: 'मोटा',
#  790: 'अफ़वाह',
#  791: 'सच',
#  792: 'राज़',
#  793: 'रख',
#  794: 'कैमरा',
#  795: 'देखा',
#  796: 'नाप',
#  797: '?',
#  798: 'निराश',
#  799: 'मोटी',
#  800: 'मुर्गियाँ',
#  801: 'कम',
#  802: 'अंडे',
#  803: 'देतीं',
#  804: 'घंटी',
#  805: 'चुकी',
#  806: 'प्रस्ताव',
#  807: 'स्वीकार',
#  808: 'पुलिस',
#  809: 'अफ़सर',
#  810: 'पुलिसवाला',
#  811: 'सीड़ियों',
#  812: 'फ़र्निचर',
#  813: 'व्यापार',
#  814: 'सारा',
#  815: 'पैसा',
#  816: 'मिला।',
#  817: 'थोड़े-बहुत',
#  818: 'पैसेवाला',
#  819: 'निशाना',
#  820: 'गरीब',
#  821: 'हमको',
#  822: 'अच्छी',
#  823: 'तरह',
#  824: 'घोड़े',
#  825: 'कम-से-कम',
#  826: 'साठ',
#  827: 'बरस',
#  828: 'होंगे।',
#  829: 'पिछले',
#  830: 'हफ़्ते',
#  831: 'प्रतियोगिता',
#  832: 'उनका',
#  833: 'आभारी',
#  834: 'ढंग',
#  835: 'आता।',
#  836: 'दे',
#  837: 'नदी',
#  838: 'छलाँग',
#  839: 'डुबकी',
#  840: 'बॉस्टन',
#  841: 'नौकर',
#  842: 'जीव',
#  843: 'विज्ञान',
#  844: 'हड़बड़ी',
#  845: 'दौड़',
#  846: 'कोरिया',
#  847: 'इतना',
#  848: 'मैरी',
#  849: 'बेटी',
#  850: 'पड़ेगी।',
#  851: 'पार्टी',
#  852: 'इसको',
#  853: 'समझो।',
#  854: 'मई',
#  855: 'आँख',
#  856: 'सूज',
#  857: 'सारे',
#  858: 'अकेला',
#  859: 'छोड़',
#  860: 'गेंद',
#  861: 'फेंकिए।',
#  862: 'जहाँ',
#  863: 'डालना',
#  864: 'डालदो।',
#  865: 'रखना',
#  866: 'रखदो।',
#  867: 'घुसाना',
#  868: 'घुसा',
#  869: 'हमेशा',
#  870: 'मांगी।',
#  871: 'नन्हा',
#  872: 'खिलौना',
#  873: 'खरीद',
#  874: 'लाई।',
#  875: 'नफ़रत',
#  876: 'पाँच',
#  877: 'लम्बी',
#  878: 'ज़िन्दगी',
#  879: 'जी।',
#  880: 'ज़िद्दी',
#  881: 'कहीं',
#  882: 'बैठ',
#  883: 'बताओ',
#  884: 'झील',
#  885: 'सारी',
#  886: 'छोड़दी।',
#  887: 'स्टेशन',
#  888: 'एक-दूसरे',
#  889: 'उन्होंने',
#  890: 'उड़ाया।',
#  891: 'उनकी',
#  892: 'ट्रेन',
#  893: 'छूट',
#  894: 'चिल्लाया।',
#  895: 'लगाई।',
#  896: 'हमने',
#  897: 'उनको',
#  898: 'परेशान',
#  899: 'थोड़ी',
#  900: 'देर',
#  901: 'चलना',
#  902: 'बकवास',
#  903: 'लिफ़्ट',
#  904: 'आएगा',
#  905: 'आएँगे',
#  906: 'जैसी',
#  907: 'करनी',
#  908: 'वैसी',
#  909: 'भरनी।',
#  910: 'बोओगे,',
#  911: 'काटोगे।',
#  912: 'करो,',
#  913: 'पाओ।',
#  914: 'भला',
#  915: 'भला।',
#  916: 'भरना।',
#  917: 'बाल',
#  918: '"मैं',
#  919: 'हूँ"',
#  920: 'लोमड़ी',
#  921: 'जंगली',
#  922: 'जानवर',
#  923: 'खरगोश',
#  924: 'कान',
#  925: 'होते',
#  926: 'पूरा',
#  927: 'माँगो।',
#  928: 'उड़ाओ।',
#  929: 'थप्पड़',
#  930: 'मजबूर',
#  931: 'ऐसी',
#  932: 'बोलो।',
#  933: 'शुरु',
#  934: 'गाना',
#  935: 'जीतीं',
#  936: 'तेज़',
#  937: 'भाग',
#  938: 'कमा',
#  939: 'लेता',
#  940: 'तीन',
#  941: 'बेटियाँ',
#  942: 'खटखटाया।',
#  943: 'सीखा।',
#  944: 'चुरा',
#  945: 'फाड़',
#  946: 'डाला।',
#  947: 'भौतिक',
#  948: 'जापानी',
#  949: 'दया',
#  950: 'चहिए।',
#  951: 'पिंजरा',
#  952: 'खाली',
#  953: 'स्कूल',
#  954: 'जाती',
#  955: 'औरत',
#  956: 'गस्सा',
#  957: 'दिलाया।',
#  958: 'चाय',
#  959: 'कॉफ़ी',
#  960: 'बुखार',
#  961: 'सात',
#  962: 'सोकर',
#  963: 'उठता',
#  964: 'अपने-आप',
#  965: 'निकाला',
#  966: 'खुद',
#  967: 'नौ',
#  968: 'पहले',
#  969: 'जाऊँगा।',
#  970: 'ब्लडी',
#  971: 'हवाईअड्डे',
#  972: 'बारे',
#  973: 'अनुपस्थित',
#  974: 'काफ़ी',
#  975: 'ठंडा',
#  976: 'रखो!',
#  977: 'पापा',
#  978: 'गुड़गुड़ा',
#  979: 'न्यू',
#  980: 'यॉर्क',
#  981: 'साढ़े',
#  982: 'छूटता',
#  983: 'सफ़ाई',
#  984: 'करूँ',
#  985: 'काले',
#  986: 'पहनती',
#  987: 'पियानो',
#  988: 'बजाना',
#  989: 'जानती',
#  990: 'नर्म',
#  991: 'दिल',
#  992: 'वाली',
#  993: 'पैसेवाली',
#  994: 'पैसेवाले',
#  995: 'कमरा',
#  996: 'दिखाया।',
#  997: 'लगभग',
#  998: 'तेल',
#  999: 'पकाया',
#  ...}

# %%
from nltk.translate.bleu_score import sentence_bleu

# %%
def evaluate(inputs):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

#  sentence = preprocess_sentence(sentence)

#  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
#  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
#                                                         maxlen=max_length_inp,
#                                                         padding='post')
#  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_out, enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([voc_output.word2index['SOS']], 0)
  #print(dec_input)
  p = []
  for t in range(max_length_targ):
    predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                         dec_hidden,
                                                         enc_out)

    # storing the attention weights to plot later on
    attention_weights = tf.reshape(attention_weights, (-1, ))
    attention_plot[t] = attention_weights.numpy()

    predicted_id = tf.argmax(predictions[0]).numpy()
    p.append(predicted_id)

    if voc_output.index2word[predicted_id] != 'EOS':
      result += voc_output.index2word[predicted_id] + ' '

    if voc_output.index2word[predicted_id] == 'EOS':
      return result, attention_plot

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, attention_plot

# %%
def plot_attention(attention, sentence, predicted_sentence):
  fig = plt.figure(figsize=(10,10))
  ax = fig.add_subplot(1, 1, 1)
  ax.matshow(attention, cmap='viridis' ,clim=[0,1])

  fontdict = {'fontsize': 14}

  ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation=90)
  ax.set_yticklabels([''] + predicted_sentence, fontdict=fontdict)

  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

  plt.show()

# %%
def translate(input, output_txt, input_txt):
  result, attention_plot = evaluate(input)

  print('Actual translation: ',output_txt)
#  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

  score = 0.0
  score = sentence_bleu(test, result)

#  attention_plot = attention_plot[:len(result.split(' ')), :len(input_txt.split(' '))]
#  plot_attention(attention_plot, input_txt.split(' '), result.split(' '))

  return score

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
dataset_test = tf.data.Dataset.from_tensor_slices((input_test, output_test))
dataset_test = dataset_test.batch(1, drop_remainder=True)
print(dataset_test)
count = 0
accuracy = 0.0
for (batch, (inp, targ)) in enumerate(dataset_test):#.take(steps_per_epoch)):
  test = ''
  for i in targ[0]:
    #print(i.numpy())
    if voc_output.index2word[i.numpy()] != 'EOS' and voc_output.index2word[i.numpy()] != 'SOS':
      test += voc_output.index2word[i.numpy()] + ' '
    
    if voc_output.index2word[i.numpy()] == 'EOS':
      break

  inp_txt = ''
  for i in inp[0]:
    if voc_input.index2word[i.numpy()] != 'EOS' and voc_input.index2word[i.numpy()] != 'SOS':
      inp_txt += voc_input.index2word[i.numpy()] + ' '
    
    if voc_input.index2word[i.numpy()] == 'EOS':
      break

  score = translate(inp, test, inp_txt)
  print('BLEU Score/Accuracy: ',score)
  count +=1
  accuracy += score
  #break

  #if count == 5:
  #  break

accuracy = accuracy / count

print('Overall Average Accuracy: ', accuracy)
# Out:
# <BatchDataset shapes: ((1, 24), (1, 27)), types: (tf.int32, tf.int32)>
# Actual translation:  मुझे एक जरूरी कॉल करनी है ।
# Predicted translation: मुझे बहुत पसंद है।
# BLEU Score/Accuracy:  0.8055344092731546
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# Actual translation:  वह अपने कमरे में रो रही थी।
# Predicted translation: वह चिट्ठी से घर से जल रहा था।
# BLEU Score/Accuracy:  0.7186082239261684
# Actual translation:  मुझे लगता है कि यहाँ कुछ ग़लतफ़ैमी हुई है।
# Predicted translation: मेरे पास तुम्हारे लिए समय नहीं है।
# BLEU Score/Accuracy:  0.7806724026248424
# Actual translation:  घूमफिरकर बात मत करो, सीधे-सीधे बोलो।
# Predicted translation: इस महीने में रहते हैं।
# BLEU Score/Accuracy:  0.7679634266158699
# Actual translation:  मैंने प्रथम पुरस्कार जीत लिया।
# Predicted translation: मुझे परिस्तिथि के साथ आने से पहले देखा था।
# BLEU Score/Accuracy:  0.7810213065790322
# Actual translation:  मेरे लिए तैरना आसान है।
# Predicted translation: यह मेरे लिए बहुत ज़्यादा है।
# BLEU Score/Accuracy:  0.8020396005825877
# Actual translation:  मैं मेट्रो लेकर स्कूल जाती हूँ।
# Predicted translation: मैं बहुत थक गया हूँ।
# BLEU Score/Accuracy:  0.8507331335123524
# Actual translation:  मैं पानी के बिना इन गोलियों को निगल नहीं सकती।
# Predicted translation: मुझे ठीक से ठीक को युनिसायकल चलाना आता है।
# BLEU Score/Accuracy:  0.7810213065790322
# Actual translation:  वह मुझसे ग़ुलाम की तरह बर्ताव करता है।
# Predicted translation: वह मुझे आने का जवाब दिया।
# BLEU Score/Accuracy:  0.8065008590125561
# Actual translation:  वह एक ज़िद्दी लड़की है।
# Predicted translation: वह सेव सड़ने आज गाँव में बहुत सारे कर्ज़ हैं।
# BLEU Score/Accuracy:  0.6828267746069693
# Actual translation:  मछली बाज़ार में कैसा चल रहा है?
# Predicted translation: टीवी चालू हैं?
# BLEU Score/Accuracy:  0.8801117367933934
# Actual translation:  वह जो भी कहे, मुझे उस पर यकीन है।
# Predicted translation: मैं तुमसे खुश नहीं सकता।
# BLEU Score/Accuracy:  0.8144476398584994
# Actual translation:  वह गरीब है, पर दिखने से खुश लगती है।
# Predicted translation: वह मुझसे थोड़े पैसे माँगे।
# BLEU Score/Accuracy:  0.7801157731069053
# Actual translation:  मैं तुम्हारे साथ आऊँगा।
# Predicted translation: मैं आपको ठीक से सुन नहीं पा सकता हूँ।
# BLEU Score/Accuracy:  0.7647860170437231
# Actual translation:  मैं मैनेजर से मिलना चाह्ता हूँ।
# Predicted translation: मैं मैनेजर से मिलना चाह्ती हूँ।
# BLEU Score/Accuracy:  0.8778107713916036
# Actual translation:  मेरे ख़याल से विदेशी भाषाएँ बहुत ही दिलचस्प होतीं हैं।
# Predicted translation: मुझे बहुत बहुत ही छोड़ देने के बदतर होने का मन करता है।
# BLEU Score/Accuracy:  0.719408902854813
# Actual translation:  वे कम-से-कम साठ बरस के तो होंगे।
# Predicted translation: उसे पैसों की कमी लगता है।
# BLEU Score/Accuracy:  0.8242367502646054
# Actual translation:  होनी को अनहोनी नहीं किया जा सकता।
# Predicted translation: जो हो चुका है सो हो चुका है।
# BLEU Score/Accuracy:  0.724724590060866
# Actual translation:  मैं इसीलिए वापस आया था।
# Predicted translation: यह वही किताब बहुत छोटा है।
# BLEU Score/Accuracy:  0.7377879464668811
# Actual translation:  जब मैं सड़क पर उसके सामने से गया, उसने जानबूझकर मुझे पहचाना नहीं।
# Predicted translation: उसने मुझे चिट्ठी की वजह से डरता था।
# BLEU Score/Accuracy:  0.8289657839357887
# Actual translation:  मैं नहीं चाहता था कि ऐसा हो।
# Predicted translation: मैं अपने होमवर्क में कुछ वापस आ जाऊँगा।
# BLEU Score/Accuracy:  0.7241577342575828
# Actual translation:  वह बड़ा होकर डॉक्टर बनना चाहता है।
# Predicted translation: वह टॉम को चिट्ठी जाने की ज़रूरत से ज़्यादा अजीब करना चिट्ठी न तो यह जैसे ही न जाने की ज़रूरत से ज़्यादा अजीब करना चिट्ठी न
# BLEU Score/Accuracy:  0.6005562870097797
# Actual translation:  वह स्कूल जाने के लिए अभी बहुत छोटी है।
# Predicted translation: वह बहुत सारे कर्ज़ हैं।
# BLEU Score/Accuracy:  0.8739351325046805
# Actual translation:  उसको मेहनत करने की आदत है।
# Predicted translation: उसे बहुत सारे शब्दों एक बड़ा सा चाहिए।
# BLEU Score/Accuracy:  0.7287557921168066
# Actual translation:  वे एक-दूसरे से नफ़रत करते थे।
# Predicted translation: उन्होंने एक-दूसरे को देखा।
# BLEU Score/Accuracy:  0.7989272423094768
# Actual translation:  मुझे शहर की ज़िन्दगी पसंद है।
# Predicted translation: मुझे अपने काम से बहुत खुश करना चाहता हूँ।
# BLEU Score/Accuracy:  0.7458878201607712
# Actual translation:  वह आज भी एक रहस्य है।
# Predicted translation: उस आदमी मत भूलना।
# BLEU Score/Accuracy:  0.7598356856515925
# Actual translation:  मौज करना।
# Predicted translation: मज़े करो।
# BLEU Score/Accuracy:  0.8801117367933934
# Actual translation:  मेरे ताऊजी क्रिकेट के शौकिया खिलाड़ी हैं।
# Predicted translation: मेरी एक चर्च हैं।
# BLEU Score/Accuracy:  0.8841583342199357
# Actual translation:  इस परिस्थिति में कठोर कदम उठाने होंगे।
# Predicted translation: उस आदमी को खतरे के फैलाव की आदत होती है।
# BLEU Score/Accuracy:  0.7503949002834928
# Actual translation:  जापान में स्कूल अप्रैल में शुरू होता है।
# Predicted translation: ग्यारह बज चुके हैं।
# BLEU Score/Accuracy:  0.8801117367933934
# Actual translation:  वह तो हसीना है।
# Predicted translation: वह भारत के लिए बहुत ही है, पर खुश है।
# BLEU Score/Accuracy:  0.6773709971213142
# Actual translation:  इस नदी में बहुत कम मछलियाँ पकड़ीं गईं।
# Predicted translation: आज ट्रेन में कम-से-कम दस साल की देखभाल है।
# BLEU Score/Accuracy:  0.7415129228605242
# Actual translation:  तम्हे क्या करना अच्छा लगता है?
# Predicted translation: आपको क्या करना अच्छा लगता है?
# BLEU Score/Accuracy:  0.8545740127924681
# Actual translation:  मुझे इस समस्या के बारे में कुछ नहीं कहना है।
# Predicted translation: मुझे इस विषय पर कुछ नहीं कहना है।
# BLEU Score/Accuracy:  0.8529987544592307
# Actual translation:  तुम यहाँ पहले आए हुए हो क्या?
# Predicted translation: तुम्हे आज रात क्या हो क्या?
# BLEU Score/Accuracy:  0.8254605646966103
# Actual translation:  दिन ढल रहा है। तुम्हे घर जाना चाहिए।
# Predicted translation: हर आदमी कुछ हो गए।
# BLEU Score/Accuracy:  0.8055344092731546
# Actual translation:  वह कामयाब होना चाहता था।
# Predicted translation: वह एक दिन में लिखी हुई था कि वह एक दिन में लिखी हुई था कि वह एक दिन में लिखी हुई था कि वह एक दिन
# BLEU Score/Accuracy:  0.5358948249862983
# Actual translation:  मैं पूरी सुबह से चिट्ठियाँ लिख रही हूँ।
# Predicted translation: मैं पूरी सुबह से चिट्ठियाँ लिख रहा हूँ।
# BLEU Score/Accuracy:  0.8801117367933934
# Actual translation:  तुम नाश्ता कितने बजे लोगे?
# Predicted translation: तुम किस समय घर के साथ क्या करोगे?
# BLEU Score/Accuracy:  0.7707713836060629
# Actual translation:  मैंने कल एक किताब खरीदी थी।
# Predicted translation: मैंने उसे कुत्ता खरीदना चाह्ता हूँ।
# BLEU Score/Accuracy:  0.7896895367562644
# Actual translation:  उसने लड़के की आँखों में देखा।
# Predicted translation: उसने पार्सल को परसों भेजा था।
# BLEU Score/Accuracy:  0.7781581271306612
# Actual translation:  क्या आपको अपना नाप पता है?
# Predicted translation: क्या आपको कम्प्यूटर का है क्या?
# BLEU Score/Accuracy:  0.7657035784021965
# Actual translation:  उसको हमेशा पैसों की कमी होती है।
# Predicted translation: उसको खुश है, पर में जी नहीं जा रहा है।
# BLEU Score/Accuracy:  0.7875110621102679
# Actual translation:  उस लड़के ने अपने सारे कपड़े उतारे।
# Predicted translation: दरवाज़े पर जो दरवाज़े पर जो दरवाज़े पर जो दरवाज़े पर जो दरवाज़े पर जो दरवाज़े पर जो दरवाज़े पर जो दरवाज़े पर जो दरवाज़े पर जो
# BLEU Score/Accuracy:  0.4671379777282001
# Actual translation:  मैं इस बार नहीं आ सकता।
# Predicted translation: मैं यह किताब नहीं है।
# BLEU Score/Accuracy:  0.8593887047640296
# Actual translation:  आ सको तो आना।
# Predicted translation: आओ ट्रेन पकड़ सकते हैं क्या?
# BLEU Score/Accuracy:  0.7009305846091448
# Actual translation:  मैं तुम्हारे बारे में सोच रहा हूँ।
# Predicted translation: मैं तुमसे प्यार है।
# BLEU Score/Accuracy:  0.8979007600118484
# Actual translation:  आप रोज़ कितने बजे उठते हैं?
# Predicted translation: तुम रोज़ कितने बजे उठा करते हो?
# BLEU Score/Accuracy:  0.8274377299117183
# Actual translation:  बौद्ध धर्म भारत में पैदा हुआ था।
# Predicted translation: उसकी कीमतें कम ही था।
# BLEU Score/Accuracy:  0.7997513045108656
# Actual translation:  इसको अपना घर ही समझो।
# Predicted translation: अपना वादा मत तोड़ो।
# BLEU Score/Accuracy:  0.7952707287670506
# Actual translation:  आप लोग यहाँ क्या करने के लिए आए हैं?
# Predicted translation: तुम यहाँ क्यों आए हो?
# BLEU Score/Accuracy:  0.8593887047640296
# Actual translation:  यह घड़ी टूटी हुई है।
# Predicted translation: यह एक है।
# BLEU Score/Accuracy:  0.8408964152537145
# Actual translation:  यहाँ बेसबॉल खेलना मना है।
# Predicted translation: आपको फिरसे बंद करना मुश्किल ही बहुत अलग होती है।
# BLEU Score/Accuracy:  0.6883338880800094
# Actual translation:  मुझसे पैसे मत माँगो।
# Predicted translation: आज गाड़ी होती है।
# BLEU Score/Accuracy:  0.7896895367562644
# Actual translation:  सौ सालों को एक शतक बुलाया जाता है।
# Predicted translation: एक पुलिस अफ़सर ने एक छोटे से पहले सारी बत्तियाँ बंद कर रहे थे।
# BLEU Score/Accuracy:  0.6865890479690392
# Actual translation:  कुछ लोग संविधान को सुधारना चाहते हैं।
# Predicted translation: कुछ लोगों को चाय रात कुछ लोगों को कुत्ते।
# BLEU Score/Accuracy:  0.7598356856515925
# Actual translation:  उसके हाथ-पैर लम्बे हैं।
# Predicted translation: उसकी एक बिल्ली है।
# BLEU Score/Accuracy:  0.851748936078004
# Actual translation:  मुझे तुमको यह बात समझाना नामुमकिन है।
# Predicted translation: मुझे जाना पड़ेगा।
# BLEU Score/Accuracy:  0.816496580927726
# Actual translation:  मुझे अभी जाना है।
# Predicted translation: मुझे उल्टी आ रही है।
# BLEU Score/Accuracy:  0.8091067115702212
# Actual translation:  पत्थर मत फेंको।
# Predicted translation: स्कूल में साल की बधाईयाँ।
# BLEU Score/Accuracy:  0.7203294535577252
# Actual translation:  तुम थके-हारे से लगते हो।
# Predicted translation: तुम उस ड्रेस के लिए बदल देंगे क्या?
# BLEU Score/Accuracy:  0.7434855737622396
# Actual translation:  पापा कभी-कभी मुझे दफ़्तर ले जाया करते थे।
# Predicted translation: उसकी गाल पर लगाया।
# BLEU Score/Accuracy:  0.8296066547537364
# Actual translation:  कमरा नम्बर पंद्राह में तौलिये नहीं हैं।
# Predicted translation: तुम्हारी बेटी अब क्या फ़र्क नहीं है।
# BLEU Score/Accuracy:  0.8109228996775397
# Actual translation:  वह बस आता ही होगा।
# Predicted translation: वह थोड़ी देर में वापस आ रहा है।
# BLEU Score/Accuracy:  0.7282376575609851
# Actual translation:  वह ईमानदार लगता है।
# Predicted translation: यह साबित नहीं था।
# BLEU Score/Accuracy:  0.7598356856515925
# Actual translation:  तुम कहाँ थे?
# Predicted translation: आप कैसे हैं?
# BLEU Score/Accuracy:  0.7875110621102679
# Actual translation:  तुम कल इस समय क्या कर रहे होगे?
# Predicted translation: तुम्हे नियमों का बात करना चाहते हो?
# BLEU Score/Accuracy:  0.7751936613371729
# Actual translation:  वह पहली बार पैरिस गई थी।
# Predicted translation: वह संगीत पढ़ने के लिए पैरिस गई।
# BLEU Score/Accuracy:  0.798359216893685
# Actual translation:  इन सवालों का जवाब देना आसान है।
# Predicted translation: ये प्रश्न सरल हैं।
# BLEU Score/Accuracy:  0.8296066547537364
# Actual translation:  किसे पता है?
# Predicted translation: कौन जाने?
# BLEU Score/Accuracy:  0.8408964152537145
# Actual translation:  वह बहुत सारे लोगों को जानता है।
# Predicted translation: उसके पास बहुत अच्छा लगता है।
# BLEU Score/Accuracy:  0.8182506116172393
# Actual translation:  मुझे लगता है वह आएगा।
# Predicted translation: मैं उसका बिलकुल भी इतने दयालु व्यक्ति से तैरना नहीं आ रहा है वह मुझसे बात नहीं आ रहा है वह मुझसे बात नहीं आ रहा है
# BLEU Score/Accuracy:  0.5683565265173782
# Actual translation:  मैं छाँओं में खड़ा हूँ।
# Predicted translation: मैं छाया में खड़ा हूँ।
# BLEU Score/Accuracy:  0.8832833620110219
# Actual translation:  मैंने उसका नाम लिख लिया जिससे कि मैं उसे भूल न जाऊँ।
# Predicted translation: मैंने अपना एक बड़ा फ़ोल्डर दूँगा।
# BLEU Score/Accuracy:  0.7707713836060629
# Actual translation:  पंछी गाते हैं।
# Predicted translation: कृपया पाँच मिनट ठहरिए।
# BLEU Score/Accuracy:  0.6828267746069693
# Actual translation:  वह भारत और चीन दोनो में बहुत प्रसिद्ध है।
# Predicted translation: वह भारत और चीन दोनो में बहुत मशहूर है।
# BLEU Score/Accuracy:  0.8462357083221157
# Actual translation:  वह हमेशा अपने बॉस की शिकायत करता रहता है।
# Predicted translation: वह किसी से पहले उठना है।
# BLEU Score/Accuracy:  0.8491821094987799
# Actual translation:  कर्मचारियों को अपने बाल छोटे कटाने होते हैं।
# Predicted translation: घायल आदमी के सामने मिलेंगे।
# BLEU Score/Accuracy:  0.7916963878457504
# Actual translation:  तुमने अपना होमवर्क कर लिया क्या?
# Predicted translation: होमवर्क किया क्या?
# BLEU Score/Accuracy:  0.8914703664390793
# Actual translation:  उसने दरवाज़े पर खटखटाया।
# Predicted translation: वह सबका मज़ाक किया।
# BLEU Score/Accuracy:  0.7952707287670506
# Actual translation:  मैं उससे नाई के यहाँ मिला।
# Predicted translation: मैं उस दुर्घटना का डर था।
# BLEU Score/Accuracy:  0.7875110621102679
# Actual translation:  मैं सोच रहा हूँ कि नौकरी लूँ या नहीं लूँ।
# Predicted translation: मैं तुम्हारे साथ सफ़र पर काम हूँ।
# BLEU Score/Accuracy:  0.7707713836060629
# Actual translation:  तुम्हारे पिता कहाँ हैं?
# Predicted translation: कपड़े रही है?
# BLEU Score/Accuracy:  0.8694417438899827
# Actual translation:  वह बहुत थका-हारा सा लगता है।
# Predicted translation: वह ग़लती से हसीना लगती है।
# BLEU Score/Accuracy:  0.7801157731069053
# Actual translation:  न वह वहाँ गया, न मैं।
# Predicted translation: वह हर सुबह सात बजे उठाने की तस्वीर पर उसने पत्र मिले मुझे उसको पत्र मिले मुझे उसको पत्र मिले मुझे उसको पत्र मिले मुझे उसको पत्र
# BLEU Score/Accuracy:  0.4653024295510498
# Actual translation:  तुमने मुझे पागल कर दिया।
# Predicted translation: तुमने मेरे पास खुशखबर है।
# BLEU Score/Accuracy:  0.7875110621102679
# Actual translation:  मेरी उससे मुलाकात नहीं हुई है।
# Predicted translation: मैंने घर को ढूँढ रहा हूँ।
# BLEU Score/Accuracy:  0.8065008590125561
# Actual translation:  बच्चे ने रोना समाप्त कर दिया।
# Predicted translation: बच्चे ने रोना बंद कर दिया।
# BLEU Score/Accuracy:  0.8485766316739435
# Actual translation:  कुत्ता रातभर भौंकता रहा।
# Predicted translation: माँ ने एक-दूसरे की थी और तुमने रात को हमेशा साफ़-सुथरा रखना चाहिए।
# BLEU Score/Accuracy:  0.5878327740374333
# Actual translation:  वे डूबते हुए जहाज़ से निकल गए।
# Predicted translation: उन्होंने डूबते हुए जहाज़ को छोड़ दिया।
# BLEU Score/Accuracy:  0.8003203203844999
# Actual translation:  हम सब उसके मज़ाक पर हँसे।
# Predicted translation: हम उनको सैर रखना।
# BLEU Score/Accuracy:  0.8408964152537145
# Actual translation:  नई सरकार ने देश को भ्रष्टाचार से मुक्त करने का वादा किया।
# Predicted translation: उस आदमी को देखा।
# BLEU Score/Accuracy:  0.8529987544592307
# Actual translation:  मेरा जन्मदिन आज से एक महीने में है।
# Predicted translation: मेरे पापा बहुत से एक है।
# BLEU Score/Accuracy:  0.8144476398584994
# Actual translation:  मैंने पुरानी गाड़ी खरीदी।
# Predicted translation: मैंने एक पुराने दोस्त से मुलाक़ात हुई।
# BLEU Score/Accuracy:  0.7598356856515925
# Actual translation:  वह अरबी बोलता है।
# Predicted translation: उसे किसी बहुत पतला है।
# BLEU Score/Accuracy:  0.7909129169328468
# Actual translation:  इस कहानी का लेखक कौन है?
# Predicted translation: तुम्हे तुम्हारा कुत्ता कैसा चल रही है?
# BLEU Score/Accuracy:  0.7115965735877551
# Actual translation:  मैंने रातभर काम किया।
# Predicted translation: मैंने पूरी रात काम किया।
# BLEU Score/Accuracy:  0.8491821094987799
# Actual translation:  मुझे बताओ क्या हुआ।
# Predicted translation: मुझे समझ में कोई आपत्ती नहीं है।
# BLEU Score/Accuracy:  0.7598356856515925
# Actual translation:  उन दिनों में मैं (रात में) जल्दी से सो जाया करता था।
# Predicted translation: मैं उससे उसके बारे में तो रह पाया तो मैं तुम्हें एक अच्छा खरीदना चाहता हूँ।
# BLEU Score/Accuracy:  0.697613262053043
# Actual translation:  मुझे पीठ की तकलीफ है I
# Predicted translation: मैं अब थक गया हूँ।
# BLEU Score/Accuracy:  0.7162326270441588
# Actual translation:  हमे गति सीमा का पालन करना चाहिए।
# Predicted translation: हमे बेसबॉल पीने को सामने रखना ही है।"
# BLEU Score/Accuracy:  0.7647860170437231
# Actual translation:  मुझे शास्त्रीय संगीत सुनने का शौक नहीं है।
# Predicted translation: मेज़
# BLEU Score/Accuracy:  0.8801117367933934
# Actual translation:  उछलो.
# Predicted translation: कूदो.
# BLEU Score/Accuracy:  0.8408964152537145
# Actual translation:  पानी कल बंद हो गया था।
# Predicted translation: उस पहाड़ पर ताला लगा हुआ था और ने रोने के अलावा और हम अंदर नहीं था।
# BLEU Score/Accuracy:  0.6736041912625804
# Actual translation:  अधिकारियों ने सच्चाई को आम जनता से छिपा कर रखा हुआ है।
# Predicted translation: उस आदमी होती है।
# BLEU Score/Accuracy:  0.8529987544592307
# Actual translation:  सरकार शिक्षा को सुधारने मे लगी हुई है।
# Predicted translation: उस लड़की ने एक आदमी को आग को आग को आग को आग को आग को आग को आग को आग को आग को आग को आग
# BLEU Score/Accuracy:  0.5839496294503805
# Actual translation:  ऐसा लगता है जैसे कि सभी लोगों को गौल्फ़ अच्छा लगता है।
# Predicted translation: वह सही है।
# BLEU Score/Accuracy:  0.8593887047640296
# Actual translation:  मुझे नहीं लगता कि टॉम परीक्षा में उत्तीर्ण होगा।
# Predicted translation: मुझे नहीं लगता कि टॉम टेस्ट में पास होगा।
# BLEU Score/Accuracy:  0.8408964152537145
# Actual translation:  उसके कपड़े हमेशा बदबू करतें हैं।
# Predicted translation: उसका ज़िन्दगी वाले थे।
# BLEU Score/Accuracy:  0.7909129169328468
# Actual translation:  पढ़के सुनाओ।
# Predicted translation: जल्दी कम समय हैं क्या?
# BLEU Score/Accuracy:  0.645777692487244
# Actual translation:  वह सोमवार को न्यूयॉर्क चला गया।
# Predicted translation: उसे पैसों की प्रतीक्षा कर दिया था।
# BLEU Score/Accuracy:  0.7121043131712586
# Actual translation:  यह सिद्धांत मेरे समझने से बाहर है।
# Predicted translation: यह मेरा बस्ता है।
# BLEU Score/Accuracy:  0.9218658175671758
# Actual translation:  मुझे कोई आवाज़ सुनाई दी।
# Predicted translation: मैंने एक साल के लिए सिगरेट पीना छोड़ दिया है।
# BLEU Score/Accuracy:  0.7146704964214272
# Actual translation:  यह कुरसी बहुत छोटी है।
# Predicted translation: यह तो बहुत रेशमी है।
# BLEU Score/Accuracy:  0.8507331335123524
# Actual translation:  मुश्किल क्या है?
# Predicted translation: तुम्हारे हो चुका है?
# BLEU Score/Accuracy:  0.8091067115702212
# Actual translation:  यहाँ तैरना बहुत ख़तरनाक है।
# Predicted translation: बहुत सारी किताबें हैं।
# BLEU Score/Accuracy:  0.8120224586769673
# Actual translation:  मैंने फ़ोन कर लिया है।
# Predicted translation: मेरा पेट गुड़गुड़ा रहा है।
# BLEU Score/Accuracy:  0.7598356856515925
# Actual translation:  अगली बार अपनी बहन को भी साथ लाना।
# Predicted translation: मेरी बहन के पास कुछ ही काफ़ी समय में बहुत लोग काफ़ी हैं।
# BLEU Score/Accuracy:  0.7039848207052138
# Actual translation:  वह आसमान की ओर देख रहा था।
# Predicted translation: वह अपने कुत्ते को आग से घर से की कमी का लड़का था।
# BLEU Score/Accuracy:  0.727427152512826
# Actual translation:  मैं मानता हूँ कि मैं ग़लत था।
# Predicted translation: मैं फिरसे चाहूँगा।
# BLEU Score/Accuracy:  0.8722877451005959
# Actual translation:  तुम्हारी नौकरी कैसी चल रही है?
# Predicted translation: बहुत समय हो तो समय हो तो समय हो तो समय हो तो समय हो तो समय हो तो समय हो तो समय हो तो समय हो
# BLEU Score/Accuracy:  0.5053483543335474
# Actual translation:  क्या तुम मुझपर यकीन करते हो?
# Predicted translation: क्या तुम मेरा यकीन है?
# BLEU Score/Accuracy:  0.8832833620110219
# Actual translation:  तुम्हारी किताब कौनसी है?
# Predicted translation: तुम्हारा कुत्ता कौनसा है?
# BLEU Score/Accuracy:  0.8566209113168688
# Actual translation:  जापान दुनिया के सबसे ताकतशाली अर्थतंत्रों में से एक है।
# Predicted translation: इस दुर्घटना का कमरा सारी समानताएं हैं।
# BLEU Score/Accuracy:  0.8125424861344327
# Actual translation:  पार्टी शुरू करते हैं।
# Predicted translation: राजा जाएगा।
# BLEU Score/Accuracy:  0.7598356856515925
# Actual translation:  वह अगले स्टॉप पर उतर गई।
# Predicted translation: उसको एक बार बाज़ार की अभिलाषा है।
# BLEU Score/Accuracy:  0.6964705665515708
# Actual translation:  इस घर में छः कमरे हैं।
# Predicted translation: उसकी हालत भारत में बहुत सारे विद्यार्थी लगता है।
# BLEU Score/Accuracy:  0.672126440078521
# Actual translation:  यहाँ धूम्रपान करना मना है।
# Predicted translation: कोई नहीं करनी चाहिए।
# BLEU Score/Accuracy:  0.7598356856515925
# Actual translation:  लोकतंत्र सरकार का सबसे घिनौना रूप है, अगर बाकी सारी तरह की सरकारों को अंदेखा किया जाए तो।
# Predicted translation: इस महीने में बहुत सारी बातें हैं।
# BLEU Score/Accuracy:  0.7863503941633413
# Actual translation:  मैं इतना थक गया हूँ कि मुझसे और चला नहीं जाएगा।
# Predicted translation: मैं अपने आलसी होने हूँ।
# BLEU Score/Accuracy:  0.8578928092681435
# Actual translation:  अपना मूँह इस ओर मोड़ो।
# Predicted translation: अपना मूँह इस तरफ़ मोड़ो।
# BLEU Score/Accuracy:  0.8944271909999159
# Actual translation:  हम सब टॉम के लिए दुःखी थे।
# Predicted translation: हम सब कुछ साल के लिए दुःखी थे I
# BLEU Score/Accuracy:  0.8408964152537145
# Actual translation:  यह लगभग सही है।
# Predicted translation: यह एक कुत्ता है।
# BLEU Score/Accuracy:  0.7364279629037999
# Actual translation:  तुम समझे नहीं।
# Predicted translation: टॉम रो पड़ा।
# BLEU Score/Accuracy:  0.6930977286178778
# Actual translation:  आप विदेश में कबसे हैं?
# Predicted translation: आप विदेश में किता समय रहे हैं?
# BLEU Score/Accuracy:  0.8340313804889192
# Actual translation:  मुझे उसके बयान की सच्चाई पर शक है।
# Predicted translation: मुझे उसके बयान की सच्चाई पर शक़ है।
# BLEU Score/Accuracy:  0.8841583342199357
# Actual translation:  तुम्हारे इगज़ैम के रिज़ल्ट बहुत अच्छे हैं।
# Predicted translation: तुम्हारी उम्र के लिए बाहर जाना है?
# BLEU Score/Accuracy:  0.8091067115702212
# Actual translation:  मैं तुम्हें एक-दो दिन में जवाब दूँगा।
# Predicted translation: मैं चाहता था कि वह जीत जाए।
# BLEU Score/Accuracy:  0.8254605646966103
# Actual translation:  यह मुफ़्त का है।
# Predicted translation: यह मुफ़्त है।
# BLEU Score/Accuracy:  0.94149097734812
# Actual translation:  मुझे इस गर्मी में पढ़ाई करना अच्छा नहीं लगता।
# Predicted translation: मुझे ठीक से नहीं लगता।
# BLEU Score/Accuracy:  0.9132675709934625
# Actual translation:  उसने किताब को फाड़ डाला।
# Predicted translation: वह किताब को बंद करना सच है।
# BLEU Score/Accuracy:  0.7730551756939454
# Actual translation:  मैं बारिश में फंस गया था और तर-तर भीग गया।
# Predicted translation: मुझे उसकी झलक दिखाई लिया था।
# BLEU Score/Accuracy:  0.7663029554391028
# Actual translation:  मेरा भाई अक्सर पूरी रात जागे रहता था।
# Predicted translation: मेरी दोनो को त्याग दिया।
# BLEU Score/Accuracy:  0.8144476398584994
# Actual translation:  मैं इस शोर को और बर्दाश्त नहीं कर सकती।
# Predicted translation: मुझसे यह एक राज़ में से आता नहीं हूँ।
# BLEU Score/Accuracy:  0.749634235443537
# Actual translation:  एसटर मुबारक हो!
# Predicted translation: ग्लास रेत से बनाया जाता है।
# BLEU Score/Accuracy:  0.6803749333171202
# Actual translation:  लंदन में धुंध छा गई थी।
# Predicted translation: एक बार चावल खाते है।
# BLEU Score/Accuracy:  0.6985342056580097
# Actual translation:  मैं उससे पूछना भूल गया।
# Predicted translation: मुझे उनकी मदद करना चाहता हूँ।
# BLEU Score/Accuracy:  0.7186082239261684
# Actual translation:  हम बात कर सकते हैं क्या?
# Predicted translation: तुम्हारे पास एक किताबें हैं?
# BLEU Score/Accuracy:  0.8335516383402117
# Actual translation:  उसको दोनो एक अध्यापक और एक इनसान के रूप में सम्मान मिला।
# Predicted translation: वह धूल की बुरी अच्छी निकल गए।
# BLEU Score/Accuracy:  0.7952707287670506
# Actual translation:  उसने मुझे अपनी शादी में आने का का न्योता दिया है।
# Predicted translation: उसने मुझे अपनी शादी में आने का का न्योता दिया है।
# BLEU Score/Accuracy:  0.8408964152537145
# Actual translation:  वह अचानक से मशहूर बन गई।
# Predicted translation: उसको अपना भविष्य असुरक्षित लगा।
# BLEU Score/Accuracy:  0.7476743906106103
# Actual translation:  मुझे केक अच्छा लगता है।
# Predicted translation: मुझे कल पसंद है।
# BLEU Score/Accuracy:  0.8757653731721587
# Actual translation:  उस आदमी ने मुझे सर पर मारा।
# Predicted translation: एक आदमी को भुजाना मत भूलना।
# BLEU Score/Accuracy:  0.7529586373193689
# Actual translation:  हमने उसका हिसाब लगा लिया।
# Predicted translation: हर आदमी के लिए दो अलग होती है।
# BLEU Score/Accuracy:  0.7340408068222942
# Actual translation:  तुमने मेरे सामान के साथ क्या किया?
# Predicted translation: क्या तुम मुझसे कितने बजे के लिए अच्छा लगता है क्या?
# BLEU Score/Accuracy:  0.7071067811865476
# Actual translation:  तुम्हे भाषण देना होगा क्या?
# Predicted translation: आपके पास भाई-बहन हो गया है क्या?
# BLEU Score/Accuracy:  0.7765453555044466
# Actual translation:  हमे पर्यावरण के प्रदूषण को रोकने का प्रयास करना चाहिए।
# Predicted translation: हमने जैसे ही उसको करने की ज़रूरत नहीं था, उसको उसकी माँ की बात समझ नहीं पाया।
# BLEU Score/Accuracy:  0.6508911374939451
# Actual translation:  तैवान में रहते समय मेरी उससे दोस्ती हुई।
# Predicted translation: जब मैं उस चाबी को ढूँढता रहा था।
# BLEU Score/Accuracy:  0.7922410709252884
# Actual translation:  मैं बहुत व्यस्थ हूँ।
# Predicted translation: मुझे शहर का नक्शा चाहिए।
# BLEU Score/Accuracy:  0.6999271023161167
# Actual translation:  उसकी नई किताब अगले महीने छपेगी।
# Predicted translation: उसकी बीमार भी सच है।
# BLEU Score/Accuracy:  0.8307018474412792
# Actual translation:  उसने मेरा बस्ता चुरा लिया।
# Predicted translation: उसने मेरे पास कुछ करवाया।
# BLEU Score/Accuracy:  0.8065008590125561
# Actual translation:  मैं ट्राफ़िक जाम में फँस गया था।
# Predicted translation: मैं ट्रैफ़िक जैम में फँस गया था।
# BLEU Score/Accuracy:  0.8823258718645413
# Actual translation:  अब तो उसे कोई चमत्कार ही बचा सकता है।
# Predicted translation: यह तो बहुत आसान है।
# BLEU Score/Accuracy:  0.81903625881272
# Actual translation:  मक्खन और पनीर दूध से बनते हैं।
# Predicted translation: कृपया अंदर आईए।
# BLEU Score/Accuracy:  0.8132882808488929
# Actual translation:  मैं आज घर साफ़ करने के बजाय सैर करने जाऊँगी।
# Predicted translation: कल मैं चाहता था कि वह मुझे उसके लिए एक अच्छा आयडिया आया।
# BLEU Score/Accuracy:  0.6627953568839928
# Actual translation:  आप किसी को बिस्तर बनाने के लिए भेज सकते हैं क्या?
# Predicted translation: आप ढूँढ रहे हो क्या?
# BLEU Score/Accuracy:  0.8694417438899827
# Actual translation:  वह बस दिन में कितनी बार चलती है?
# Predicted translation: सभी लोग समय घर में पढ़ाना छोड़े हुए हैं?
# BLEU Score/Accuracy:  0.7503949002834928
# Actual translation:  हम अच्छे दोस्त हैं।
# Predicted translation: हम घर के लिए दुःखी थे I
# BLEU Score/Accuracy:  0.6756000774035172
# Actual translation:  मुझे तुम्हारी दया नहीं चहिए।
# Predicted translation: मैं तुमसे बात का सोफ़ा नहीं खरीदना है।
# BLEU Score/Accuracy:  0.7598356856515925
# Actual translation:  मैं उसे लेलूँगा।
# Predicted translation: मैं घर पर ही रहूँगा।
# BLEU Score/Accuracy:  0.8091067115702212
# Actual translation:  उसने पैसों के लिए शादी की।
# Predicted translation: उसने उस आदमी किया।
# BLEU Score/Accuracy:  0.8722877451005959
# Actual translation:  सारा ब्रॅड कहाँ चला गया?
# Predicted translation: इस और कैसा चल रहा है?
# BLEU Score/Accuracy:  0.7997513045108656
# Actual translation:  मुझे तैरना आता है।
# Predicted translation: मैं तैर सकता हूँ।
# BLEU Score/Accuracy:  0.816496580927726
# Actual translation:  मैं तुम्हें फिरसे देखकर बहुत खुश हूँ।
# Predicted translation: मैं तुम्हें एक हद तक तुम्हें कुछ सामान ख़रीदने जाऊँगी।
# BLEU Score/Accuracy:  0.7344112539787184
# Actual translation:  तुम्हें कुत्ते को बांध देना चाहिए जिससे कि वह किसी को काट न ले।
# Predicted translation: तुम्हे अपने हाथ एक भी रखना है कि तुम कामयाब हो जाएगा।
# BLEU Score/Accuracy:  0.7490551432883844
# Actual translation:  वह खुशी से उछल पड़ी।
# Predicted translation: वह भारत में काम किया।
# BLEU Score/Accuracy:  0.6904573083274563
# Actual translation:  उनके इनवेस्टमेंट पर ८ प्रतिशत का फ़ायदा हुआ।
# Predicted translation: उन्होंने हमको एक छोटे से एक छोटे से एक छोटे से एक छोटे से एक छोटे से एक छोटे से एक छोटे से एक छोटे से एक
# BLEU Score/Accuracy:  0.5689195351585976
# Actual translation:  वह कल पार्टी में नहीं आया।
# Predicted translation: उसे किसी रात आराम से शाम तक देखा था।
# BLEU Score/Accuracy:  0.7022798316312892
# Actual translation:  काम कल तक खतम होना होगा।
# Predicted translation: यह एक समिति के बारे में बीवा अफ़सर उससे बात करना ज़रूरी है।
# BLEU Score/Accuracy:  0.6042750794713536
# Actual translation:  उसकी खिड़की के बाहर इतना शोर हो रहा था कि वह सो नहीं पा रहा था।
# Predicted translation: वह लम्बी सुबह से निकाल दिया आ रहा है।
# BLEU Score/Accuracy:  0.7647860170437231
# Actual translation:  भारत में कल एक बड़ा भूकम्प हुआ था।
# Predicted translation: वह बुखार से राज़ी नहीं था।
# BLEU Score/Accuracy:  0.7989272423094768
# Actual translation:  क्या आपके पापा अध्यापक हैं?
# Predicted translation: क्या तुम्हारे पापा टीचर हैं?
# BLEU Score/Accuracy:  0.7847813466510527
# Actual translation:  नया क्या है?
# Predicted translation: क्या नया है?
# BLEU Score/Accuracy:  0.912167909070388
# Actual translation:  उसे संत्रे अच्छे लगते हैं।
# Predicted translation: उसे नारंगी अच्छे लगते हैं।
# BLEU Score/Accuracy:  0.8773826753016616
# Actual translation:  इस महीने दो हत्याएँ हुईं हैं।
# Predicted translation: इस महीने दो क़त्ल हुए हैं।
# BLEU Score/Accuracy:  0.8907817059279295
# Actual translation:  उस दिन के लिए बहुत बहुत धन्यवाद।
# Predicted translation: यहाँ पिछले कुछ ही लोगों को अक्सर सच है।
# BLEU Score/Accuracy:  0.7400828044922853
# Actual translation:  ये चिड़ियाँ हैं।
# Predicted translation: ये किताबें मेरीं हैं।
# BLEU Score/Accuracy:  0.7997513045108656
# Actual translation:  मुझे अपना नाम और फ़ोन नम्बर बताईये।
# Predicted translation: वह गाना सभी को समय की तरह से जाकर भारत से जाकर भारत से जाकर भारत से जाकर भारत से जाकर भारत से जाकर भारत से जाकर
# BLEU Score/Accuracy:  0.532422158401508
# Actual translation:  तुम नाकामयाब इसलिए रहे क्योंकि तुमने पूरी तरह मेहनत नहीं लगाई।
# Predicted translation: हर साल का भयानक है।
# BLEU Score/Accuracy:  0.8408964152537145
# Actual translation:  तुम्हे अपनी रिपोर्ट मुझे सोमवार को सौंप देनी चाहिए।
# Predicted translation: तुम्हे अपने हाथ के मालिक हैं क्या?
# BLEU Score/Accuracy:  0.7952707287670506
# Actual translation:  तुम कैसे हो?
# Predicted translation: आप कैसे हैं?
# BLEU Score/Accuracy:  0.8566209113168688
# Actual translation:  तुम्हे इस तरह की आदत तोड़ देनी चाहिए।
# Predicted translation: आप ये जवाब रखना थी।
# BLEU Score/Accuracy:  0.7952707287670506
# Actual translation:  मैं यहाँ तीन महीनों के लिए रहूँगा।
# Predicted translation: फिर हुआ।
# BLEU Score/Accuracy:  0.8633400213704505
# Actual translation:  मातापिता अपने बच्चों की सुरक्षा के लिए ज़िम्मेदार होते हैं।
# Predicted translation: तुम्हारे पास एक दिन में समय हो रही है।
# BLEU Score/Accuracy:  0.8566209113168688
# Actual translation:  तुम यह किताब न ही पढ़ो बेहतर होगा।
# Predicted translation: तुम्हे आसमान में तो होगा।
# BLEU Score/Accuracy:  0.8065008590125561
# Actual translation:  उसने जैसे बताया था मैंने वैसे किया।
# Predicted translation: मैं किसी को अपनी साईकल चलाकर काम करती है।
# BLEU Score/Accuracy:  0.7153784423080968
# Actual translation:  क्या यह काला नहीं है?
# Predicted translation: आपका कोई जगह नहीं हो क्या?
# BLEU Score/Accuracy:  0.7801157731069053
# Actual translation:  कोई नहीं बता सका उसका वह कहने से मतलब क्या था।
# Predicted translation: टॉम को कहा था कि वह उनके लिए करने के साथ आएगा।
# BLEU Score/Accuracy:  0.7387670965262431
# Actual translation:  समुद्र तट कहां है?
# Predicted translation: कपड़े बदलने का कमरा कहाँ पर है?
# BLEU Score/Accuracy:  0.7282376575609851
# Actual translation:  ईश्वर उनकी मदद करता है जो स्वयं की मदद करते हैं।
# Predicted translation: जब मैं वहाँ पहुँचा, तुम्हें टॉम
# BLEU Score/Accuracy:  0.7657035784021965
# Actual translation:  सर्दी आ रही है।
# Predicted translation: यह एक लम्बा है ना?
# BLEU Score/Accuracy:  0.6773709971213142
# Actual translation:  उसको अहंकारी होने की आदत है।
# Predicted translation: उसको अभिमानी होने की आदत है।
# BLEU Score/Accuracy:  0.8618476389178121
# Actual translation:  उनको दूर से बंदूक की आवाज़ सुनाई दी।
# Predicted translation: उन्होंने एक और दो लड़के हैं।
# BLEU Score/Accuracy:  0.7847813466510527
# Actual translation:  वह टेनिस अच्छा खेलता है।
# Predicted translation: उसका पापा अक्सर है, रहती है।
# BLEU Score/Accuracy:  0.7463819494944633
# Actual translation:  उसने केक को छः टुकड़ो में काट कर, हर बच्चे हो एक टुकड़ा दिया।
# Predicted translation: उसने किसी को खाना खाने के पीछे उनकी माँ हस्पताल में से पहले अपने देश को खाना खाने के पीछे उनकी माँ हस्पताल में से पहले अपने
# BLEU Score/Accuracy:  0.5897492448660925
# Actual translation:  हाँ शायद मैं दुखी हूँ, पर मुझे अपनी जान लेने का इरादा नहीं है।
# Predicted translation: मैं इतना सारा काम खतम कर पाऊँगा।
# BLEU Score/Accuracy:  0.7922410709252884
# Actual translation:  जल्दी घर आजाओ।
# Predicted translation: हमारे साथ गाड़ियाँ ख़रीदीं हैं क्या?
# BLEU Score/Accuracy:  0.6345814629568174
# Actual translation:  मुझे कॉफ़ी पीना पसंद नहीं।
# Predicted translation: मुझे यह किताब को काम पर चल नहीं करता।
# BLEU Score/Accuracy:  0.7647860170437231
# Actual translation:  उसने कोई बहाना बना लिया।
# Predicted translation: वह मुर्झाई हुई थी।
# BLEU Score/Accuracy:  0.7162326270441588
# Actual translation:  फ़ुटबॉल मेरा सबसे पसंदीता खेल है।
# Predicted translation: यह मेरे लिए बहुत नर्म लगता है।
# BLEU Score/Accuracy:  0.7887781797427305
# Actual translation:  इस दीवार पर मत झुँको।
# Predicted translation: उसके नाना की उम्र में बात मत तोड़ो।
# BLEU Score/Accuracy:  0.7259795291154771
# Actual translation:  तुम्हें जाना होगा।
# Predicted translation: यहाँ हो गया था।
# BLEU Score/Accuracy:  0.7825422900366437
# Actual translation:  हम जल्दी में थे।
# Predicted translation: हम जल्दी में हैं।
# BLEU Score/Accuracy:  0.8841583342199357
# Actual translation:  तुम्हारी उम्र जितनी बड़ी होती है, तुम्हारे लिए कोई भाषा सीखना उतना ही कठिन होता है।
# Predicted translation: आज से पहले चीनी के मुताबिक उसकी बुराई आदमी को भारत की नकल करने की नकल करने की नकल करने की नकल करने की नकल करने की
# BLEU Score/Accuracy:  0.6471892368478446
# Actual translation:  मुझे नहीं पता वह कैसे निकल भागा।
# Predicted translation: मुझे नहीं पता मेरे पास जाना चाह्ता हूँ।
# BLEU Score/Accuracy:  0.7691605673134586
# Actual translation:  मेरे मामा क्रिकेट के शौकिया खिलाड़ी हैं।
# Predicted translation: मेरी एक चर्च हैं।
# BLEU Score/Accuracy:  0.8841583342199357
# Actual translation:  अपने मोज़े उतारिए।
# Predicted translation: दरवाज़े पर जाने से पहले अपने हाथ बनने की चोटी मूँगफलियाँ गए।
# BLEU Score/Accuracy:  0.6921489273129074
# Actual translation:  वह बच्चे की तरह सो रहा है।
# Predicted translation: वह अभी बहुत नर्म लगता है।
# BLEU Score/Accuracy:  0.8065008590125561
# Actual translation:  तुमने कभी क्वाला देखा है?
# Predicted translation: आपने कभी किताब लिखी है क्या?
# BLEU Score/Accuracy:  0.8335516383402117
# Actual translation:  मुझे नहीं पता कि वह आएगी कि नहीं।
# Predicted translation: मुझे नहीं पता वह मेरे साथ वहाँ जाएगी कि नहीं।
# BLEU Score/Accuracy:  0.7909129169328468
# Actual translation:  मेज़ पर किताब है।
# Predicted translation: इस कमरे में से सारी तस्वीरें हैं।
# BLEU Score/Accuracy:  0.7364279629037999
# Actual translation:  वह हर सुबह अखबार पढ़ता है।
# Predicted translation: वह बहुत अच्छा सवाल है।
# BLEU Score/Accuracy:  0.8316033157750904
# Actual translation:  अगर लम्बी ज़िन्दगी जीना चाहते हो तो सिगरेट पीना छोड़ दो।
# Predicted translation: हमें अपने सामान
# BLEU Score/Accuracy:  0.8660254037844387
# Actual translation:  उसने मुझसे मदद मांगी।
# Predicted translation: उसने मुझसे एक भाई का कोई पैसे माँगे।
# BLEU Score/Accuracy:  0.7384102902900735
# Actual translation:  मुझे नौकरी से निकाला नहीं गया। मैंने खुद ही नौकरी छोड़ दी।
# Predicted translation: मैं कल का शौकीन हूँ।
# BLEU Score/Accuracy:  0.8694417438899827
# Actual translation:  ताज महल विश्व के सात आश्चर्यों में से एक है।
# Predicted translation: एक आदमी को लौटाना मत भूलना।
# BLEU Score/Accuracy:  0.7730551756939454
# Actual translation:  मुश्किल कहाँ है?
# Predicted translation: मुश्किल क्या है?
# BLEU Score/Accuracy:  0.9166068134248218
# Actual translation:  माफ़ कीजिए पर हम आपकी मदद नहीं कर सकते।
# Predicted translation: हम जो नहीं जानते थे?
# BLEU Score/Accuracy:  0.8307018474412792
# Actual translation:  मैं तुम्हारे बिना जी नहीं सकता।
# Predicted translation: मैं तुम्हारे बगैर जी नहीं सकती।
# BLEU Score/Accuracy:  0.8660254037844387
# Actual translation:  कनाडा जापान से बड़ा है।
# Predicted translation: यह किताब बहुत पतली है।
# BLEU Score/Accuracy:  0.7679634266158699
# Actual translation:  टॉम मेरा दोस्त है।
# Predicted translation: टॉम मेरा लड़का है।
# BLEU Score/Accuracy:  0.851748936078004
# Actual translation:  यह उसपर भी लागु होता है।
# Predicted translation: यह गाड़ी करना है।
# BLEU Score/Accuracy:  0.8408964152537145
# Actual translation:  मेरे ख़याल से वह कभी भी वापस नहीं आएगा।
# Predicted translation: मैं कल उससे कभी भी उसके आने से पहले भी उसके आने से पहले भी उसके आने से पहले भी उसके आने से पहले भी उसके आने
# BLEU Score/Accuracy:  0.5890198071748992
# Actual translation:  उन सभी के पास साईकल है।
# Predicted translation: यह साईकल हवा के लिए बहुत मज़ेदार महसूस हैं।
# BLEU Score/Accuracy:  0.6904573083274563
# Actual translation:  हमने मुनाफ़े को अपने बीच बाँटा।
# Predicted translation: हम हम सब बोर हो गए।
# BLEU Score/Accuracy:  0.7400828044922853
# Actual translation:  बत्तियाँ पूरी रात से जल रहीं हैं।
# Predicted translation: यह तो सच है।
# BLEU Score/Accuracy:  0.8566209113168688
# Actual translation:  तू कहाँ रहता है?
# Predicted translation: आप कहाँ रहते हैं?
# BLEU Score/Accuracy:  0.8408964152537145
# Actual translation:  इस दवाई को हर छः घंटे लेना।
# Predicted translation: उस हाथ से डरता था।
# BLEU Score/Accuracy:  0.7790872728179328
# Actual translation:  उसने बच्चे को रोते हुए छोड़ दिया।
# Predicted translation: उसने पार्सल को पालतू मौज करी।
# BLEU Score/Accuracy:  0.7952707287670506
# Actual translation:  तुम यहाँ सारे के सारे पेड़ काट डालोगे क्या?
# Predicted translation: तुम कब लौट कर आओगे?
# BLEU Score/Accuracy:  0.861173529963367
# Actual translation:  आपको मुझे क्षमा करना होगा।
# Predicted translation: तुम्हे मुझे माफ़ करना होगा।
# BLEU Score/Accuracy:  0.8408964152537145
# Actual translation:  यह मुफ़्त का है।
# Predicted translation: यह एक लम्बा है ना?
# BLEU Score/Accuracy:  0.8055344092731546
# Actual translation:  वह अपनी माँ जैसी सुंदर है।
# Predicted translation: उसने अपने हाथ अकेले जाने से राज़ी थे।
# BLEU Score/Accuracy:  0.733503637924837
# Actual translation:  वह साधा आदमी है।
# Predicted translation: वह ज़रूरत है।
# BLEU Score/Accuracy:  0.7730551756939454
# Actual translation:  कृपया ध्यान दीजिए।
# Predicted translation: क्या तुम टॉम की रक्षा करने के लिए एक बीटल्स का जवाब देना।
# BLEU Score/Accuracy:  0.6744322250214191
# Actual translation:  वह गाने लगी।
# Predicted translation: वह पुलिस अफ़सर बन गया।
# BLEU Score/Accuracy:  0.7679634266158699
# Actual translation:  अफ़्रीका को एक समय में अंधेर महाद्वीप बुलाया जाता था।
# Predicted translation: बाग के समय की पहचान में एक बार फिरसे पहले जूते उतारने होंगे।
# BLEU Score/Accuracy:  0.7567022758746456
# Actual translation:  वह मेरे बजाय वहां गया।
# Predicted translation: वह उसकी झलक के बारे में था।
# BLEU Score/Accuracy:  0.7730551756939454
# Actual translation:  बारह बजने वाले हैं।
# Predicted translation: आज स्कूल एक अप्रैल है।
# BLEU Score/Accuracy:  0.7427498127683173
# Actual translation:  उसकी अपने पहले पति से एक लड़की थी।
# Predicted translation: उसकी हालत भारत के लिए फूल लाईं।
# BLEU Score/Accuracy:  0.7825422900366437
# Actual translation:  मुझे एक कप चाय दीजिए।
# Predicted translation: वह एक बार मिलना है।
# BLEU Score/Accuracy:  0.7691605673134586
# Actual translation:  आप कहाँ थे?
# Predicted translation: आप कैसे हैं?
# BLEU Score/Accuracy:  0.8566209113168688
# Actual translation:  मैं थक गया हूँ।
# Predicted translation: मैं हँसा।
# BLEU Score/Accuracy:  0.9457416090031758
# Actual translation:  वह कभी-कभी उससे भारत की बात करने की कोशिश किया करती थी।
# Predicted translation: वह काम नहीं देखा था।
# BLEU Score/Accuracy:  0.8307018474412792
# Actual translation:  उन्हें अपनी टीचर से डाँट पड़ी।
# Predicted translation: वे मेरी नब्ज़ ली।
# BLEU Score/Accuracy:  0.816496580927726
# Actual translation:  वह सोना का बहाना कर रही थी।
# Predicted translation: वह अपने कुत्ते को पानी में बहुत सारे कष्ट दिया।
# BLEU Score/Accuracy:  0.7071067811865476
# Actual translation:  मेरे दोस्तों ने मेरा जन्मदिन मनाया।
# Predicted translation: मेरी मेरा भाई के साथ लड़ाई हुई है।
# BLEU Score/Accuracy:  0.668740304976422
# Actual translation:  वह पुलिसवाला बन गया।
# Predicted translation: वह पुलिस अफ़सर बन गया।
# BLEU Score/Accuracy:  0.8832833620110219
# Actual translation:  वह खबर सुनकर हैरान रह गई।
# Predicted translation: वह हमेशा साफ़-सुथरा ले जाता था।
# BLEU Score/Accuracy:  0.7071067811865476
# Actual translation:  आपको कहीं जाना है?
# Predicted translation: तुम्हें कहीं जाना है?
# BLEU Score/Accuracy:  0.8210967436686386
# Actual translation:  आसमान साफ़ है।
# Predicted translation: पतंग उड़ाना खतरनाक हो गए।
# BLEU Score/Accuracy:  0.6930977286178778
# Actual translation:  मुझे ट्राए करने दो।
# Predicted translation: मुझे देखने दो।
# BLEU Score/Accuracy:  0.8801117367933934
# Actual translation:  हकला क्यों रहे हो?
# Predicted translation: तुम कभी अफ़्रीका गए हुए हैं?
# BLEU Score/Accuracy:  0.724724590060866
# Actual translation:  उसके पास थोड़े-बहुत पैसे हैं।
# Predicted translation: उसके पास कुछ ही बहुत कठिन है।
# BLEU Score/Accuracy:  0.8113449257895087
# Actual translation:  मुझे पूरा विश्वास है कि उसने कोई भी ग़लत काम नहीं किया।
# Predicted translation: मुझे लगा कि तुमसे यहाँ मुलाकात होगी।
# BLEU Score/Accuracy:  0.82330698369719
# Actual translation:  खाना ठंडा हो रहा है।
# Predicted translation: दरवाज़े के लिए ज़िम्मेदार होती है।
# BLEU Score/Accuracy:  0.668740304976422
# Actual translation:  वह अपनी ज़िंदगी को भारत में बीमारों का इलाज करने में समर्पित करना चाहता है।
# Predicted translation: वह अपने हाथ में मुझे पैसे दिया।
# BLEU Score/Accuracy:  0.8274377299117183
# Actual translation:  मैं निराश था कि तुमने फ़ोन नहीं किया।
# Predicted translation: मैं आपकी मदद कर सकता हूँ।
# BLEU Score/Accuracy:  0.8065008590125561
# Actual translation:  उसको मेरी कामयाबी से जलन थी।
# Predicted translation: वह कल मेरे बारे में मदद करी थी।
# BLEU Score/Accuracy:  0.7657035784021965
# Actual translation:  यह जीत तो बहुत आसान थी।
# Predicted translation: बहुत ज़्यादा बहुत सारी किताबें हैं।
# BLEU Score/Accuracy:  0.7434855737622396
# Actual translation:  ये अजीब है, नहीं?
# Predicted translation: इसका अभी तक नहीं आ सकता है।
# BLEU Score/Accuracy:  0.7071067811865476
# Actual translation:  तुम यह किताब मुफ़्त में ले सकते हो।
# Predicted translation: तुम यह करने के साथ कोई फ़ायदा नहीं है।
# BLEU Score/Accuracy:  0.7875110621102679
# Actual translation:  उस आदमी ने मेरी ओर देखा।
# Predicted translation: उस घर में एक आदमी ने उसकी मंजिल तक पहले पानी के लिए मेज़ पर हाथ हाथ उसे मलेरिया हो गए।
# BLEU Score/Accuracy:  0.6094183098284
# Actual translation:  उसे मेहनत करने की आदत है।
# Predicted translation: उसे सब टेनिस देखना बहुत ज़्यादा करता है।
# BLEU Score/Accuracy:  0.7355282324972029
# Actual translation:  इस मकान में ग्यारह कमरे हैं।
# Predicted translation: यह सब नौकरी के लिए सिगरेट पीना लड़की है।
# BLEU Score/Accuracy:  0.7355282324972029
# Actual translation:  वह एक बार फिर देर से आई।
# Predicted translation: वह बहुत शौकीन हूँ।
# BLEU Score/Accuracy:  0.749634235443537
# Actual translation:  मेरे सिर में दर्द हो रहा है।
# Predicted translation: मुझे सिरदर्द हो रहा है।
# BLEU Score/Accuracy:  0.8578928092681435
# Actual translation:  आपको ऐमब्यूलेंस की ज़रूरत है क्या?
# Predicted translation: क्या तुम इन वाक्यों का पालन करना सिखा सकते हो?
# BLEU Score/Accuracy:  0.7638455118619067
# Actual translation:  आसमान से वह नदी एक विशाल सांप की तरह दिख रही थी।
# Predicted translation: एक आदमी को मेज़ की कमी की कमी की कमी की कमी की कमी की कमी की कमी की कमी की कमी की कमी की कमी की
# BLEU Score/Accuracy:  0.537284965911771
# Actual translation:  तुम्हारी योजना के लिए बहुत सारे पैसे की ज़रूरत है।
# Predicted translation: आपका दल हमसे बेहतर है |
# BLEU Score/Accuracy:  0.8578928092681435
# Actual translation:  तूफ़ान ने पूरे शहर को तबाह कर दिया।
# Predicted translation: तूफ़ान ने पूरे नगर को नष्ट कर दिया।
# BLEU Score/Accuracy:  0.816496580927726
# Actual translation:  हम चाय चीनी के साथ लेते हैं।
# Predicted translation: हम चाय चीनी डालकर पीते हैं।
# BLEU Score/Accuracy:  0.855526185871245
# Actual translation:  वह अंग्रेज़ी नागरिक है पर भारत में रहता है।
# Predicted translation: उसके पास बैंक में बहुत सारे कष्ट सहने पड़े थे।
# BLEU Score/Accuracy:  0.7516200388933441
# Actual translation:  आखिरकार हमे सच्चाई का पता चल गया।
# Predicted translation: डॉक्टर ने उसे भी जाए, कि उसको नहीं दे लेगा।
# BLEU Score/Accuracy:  0.7226568811456053
# Actual translation:  इस बात को बच्चे भी समझते हैं।
# Predicted translation: ऐसी वफ़ादारी खरीदी नहीं लगता है वह फिरसे आईएगा।
# BLEU Score/Accuracy:  0.6756000774035172
# Actual translation:  वह अमरीका से वापस आ गया।
# Predicted translation: उसे सब काम किया।
# BLEU Score/Accuracy:  0.8282477531331041
# Actual translation:  क्या हमे कल सुबह जल्दी उठना है?
# Predicted translation: तुम यह सलाह हो तो हमसे मिलने हो तो हमसे मिलने हो तो हमसे मिलने हो तो हमसे मिलने हो तो हमसे मिलने हो तो हमसे मिलने
# BLEU Score/Accuracy:  0.5442191092561398
# Actual translation:  उसने मुझे अपना कमरा दिखाया।
# Predicted translation: उसने मुझे रहने के बारे में अकेले जाने का शौकीन हूँ।
# BLEU Score/Accuracy:  0.7071067811865476
# Actual translation:  वह हमेशा मन लगाकर काम करती है।
# Predicted translation: वह मेरा दोस्त से नहीं मिला।
# BLEU Score/Accuracy:  0.8091067115702212
# Actual translation:  मेरे पास ज़्यादा समय नहीं है।
# Predicted translation: मुझे यह किताब नहीं है।
# BLEU Score/Accuracy:  0.8316033157750904
# Actual translation:  हम संगीत की पढ़ाई करते हैं।
# Predicted translation: हम जल्दबाज़ी में बाहर जाओ।
# BLEU Score/Accuracy:  0.7801157731069053
# Actual translation:  आसपास कोई नहीं है।
# Predicted translation: ये ही जाती है।
# BLEU Score/Accuracy:  0.7952707287670506
# Actual translation:  तुम किस तरह का काम करोगे?
# Predicted translation: तुम्हारा दोस्त क्या है?
# BLEU Score/Accuracy:  0.8228020420406904
# Actual translation:  पापा बाथरूम में दाढ़ी बना रहे हैं।
# Predicted translation: इस तरफ़ उड़ जाना हैं।
# BLEU Score/Accuracy:  0.7997513045108656
# Actual translation:  उसकी निराशा सभी आसानी से दिख सकते थे।
# Predicted translation: वह आगे से इनकार कर सकते थे।
# BLEU Score/Accuracy:  0.7916963878457504
# Actual translation:  बच्चों को दवाईयों से दूर रखना चहिए।
# Predicted translation: इसको नीचे पीने के लिए कुछ पीने के लिए कुछ पीने के लिए कुछ पीने के लिए कुछ पीने के लिए कुछ पीने के लिए कुछ पीने
# BLEU Score/Accuracy:  0.5336172773868456
# Actual translation:  अंग्रेज़ी वैश्विक भाषा है।
# Predicted translation: अंग्रेज़ी सारी दुनिया की भाषा है।
# BLEU Score/Accuracy:  0.8529987544592307
# Actual translation:  जितनी किताबें पढ़ सकते हो पढ़ो।
# Predicted translation: एक अरब येन होंगे?
# BLEU Score/Accuracy:  0.816496580927726
# Actual translation:  ऐसी बात मत बोलो।
# Predicted translation: उस चाबी के साथतानी मत करो!
# BLEU Score/Accuracy:  0.7377879464668811
# Actual translation:  आज मौसम बहुत गरम है।
# Predicted translation: चीन की है?
# BLEU Score/Accuracy:  0.7226568811456053
# Actual translation:  बरफ़ गिर रही है।
# Predicted translation: ठंड हो रही है।
# BLEU Score/Accuracy:  0.7952707287670506
# Actual translation:  हम सब एक-साथ खड़े हो गए।
# Predicted translation: हम चाय चीनी डालते हैं।
# BLEU Score/Accuracy:  0.7427498127683173
# Actual translation:  मुझे इतिहास में दिलचस्पी है।
# Predicted translation: मुझे सिरदर्द हो रहा है।
# BLEU Score/Accuracy:  0.8578928092681435
# Actual translation:  मैं अपनी मम्मी के लिए तोह्फ़ा ढूँढ रहा हूँ।
# Predicted translation: मैं उससे फ़ोन से प्यार करता हूँ
# BLEU Score/Accuracy:  0.8660254037844387
# Actual translation:  उसके नसीब में उससे फिरसे मिलना नहीं लिखा हुआ था।
# Predicted translation: वह मेरे पीछे अभी तक कभी भी पसंद नहीं करता था।
# BLEU Score/Accuracy:  0.7291155827927387
# Actual translation:  वह देशद्रोही बन गया।
# Predicted translation: वह खेत के लिए बताया की कमी थी।
# BLEU Score/Accuracy:  0.7340408068222942
# Actual translation:  मज़े करना।
# Predicted translation: मज़े करो।
# BLEU Score/Accuracy:  0.9457416090031758
# Actual translation:  मुझे यह बताओ, कि टॉम ऐसा कर क्यों रहा है।
# Predicted translation: मुझे उसके काम उसके काम उसके काम उसके काम उसके काम उसके काम उसके काम उसके काम उसके काम उसके काम उसके काम उसके काम उसके काम
# BLEU Score/Accuracy:  0.5060373107447631
# Actual translation:  मेरी सोच तुम्हारी सोच से बिलकुल अलग है।
# Predicted translation: मेरे पापा अभी भी नहीं कर सकता है कि मुझे इस विषय पर नहीं है।
# BLEU Score/Accuracy:  0.7041908148225626
# Actual translation:  टोक्यो बहुत बड़ा शहर है।
# Predicted translation: उसने मुझे वह अच्छा लगता है।
# BLEU Score/Accuracy:  0.7311104457090247
# Actual translation:  वह फ़्लैट में अकेले रहती है।
# Predicted translation: वह अपने कर्मचारियों के साथ अच्छे से निभता है।
# BLEU Score/Accuracy:  0.7291155827927387
# Actual translation:  मैं वापस आऊँगा।
# Predicted translation: मैं कभी वापस नहीं आऊँगा।
# BLEU Score/Accuracy:  0.8491821094987799
# Actual translation:  तुम राज़ रख सकते हो क्या?
# Predicted translation: क्या तुम इसे राज़ रख सकते हो?
# ...
# BLEU Score/Accuracy:  0.725205974975922
# Actual translation:  बच्चा की नींद आधी रात में खुल गई।
# Predicted translation: उसके भाग्य में छलाँग लगादी।
# BLEU Score/Accuracy:  0.8091067115702212
# Actual translation:  क्या आप थोड़ी देर बाद फिरसे फ़ोन कर सकतें हैं?
# Predicted translation: आप बाहर नहीं गए थे क्या?
# BLEU Score/Accuracy:  0.8944271909999159
# Actual translation:  हम आखिरकार झील तक पहुँच गए।
# Predicted translation: आखिरकार उसको था अमीर दी।
# BLEU Score/Accuracy:  0.7952707287670506
# Actual translation:  मैं तुमपर भरोसा कर रहा हूँ।
# Predicted translation: मैं तुम्हारे पिताजी से मिलना चाह्ता हूँ।
# BLEU Score/Accuracy:  0.7644270467420534
# Actual translation:  मैंने उसे दस डॉलर के लिए बेच दिया।
# Predicted translation: मैंने अपनी मम्मी की बजाय फ़्रानसीसी सीखी ।
# BLEU Score/Accuracy:  0.7415129228605242
# Actual translation:  पानी का पाइप फट गया।
# Predicted translation: एक आदमी होती है।
# BLEU Score/Accuracy:  0.6964705665515708
# Actual translation:  मैं बेहोश हो गया।
# Predicted translation: मैं बेहोशी में चला गया।
# BLEU Score/Accuracy:  0.8578928092681435
# Actual translation:  हमने पूरी गर्मी उनके साथ बिताई।
# Predicted translation: हम थोड़ी जगह होता है।
# BLEU Score/Accuracy:  0.7997513045108656
# Actual translation:  बाहर नहीं जाना चाहते हो क्या?
# Predicted translation: यहाँ छूट सकते हो।
# BLEU Score/Accuracy:  0.816496580927726
# Actual translation:  वह कैनटीन में लन्च खाता है।
# Predicted translation: वह हमेशा अच्छी शिक्षा दी।
# BLEU Score/Accuracy:  0.8065008590125561
# Actual translation:  इस कविता का तुम क्या मतलब निकालते हो?
# Predicted translation: इस कविता क्या आप क्या अर्थ निकालते हैं?
# BLEU Score/Accuracy:  0.7825422900366437
# Actual translation:  उसे अपनी उम्र के बारे में सोचना चाहिए था।
# Predicted translation: वह अपने प्रयोगों में शिक़ायत करी।
# BLEU Score/Accuracy:  0.8282477531331041
# Actual translation:  हार मत मान लो।
# Predicted translation: सारे पंछी उड़ नहीं है।
# BLEU Score/Accuracy:  0.7146704964214272
# Actual translation:  मैं बड़े पैमाने पर व्यापार कर रहा हूँ।
# Predicted translation: मैं साईकल मेरे साथ गेंद खेलने कहाँ पर शर्म है।
# BLEU Score/Accuracy:  0.7387670965262431
# Actual translation:  मुझे उसका पता पता है।
# Predicted translation: मुझे उसका पता पता है।
# BLEU Score/Accuracy:  0.8931539818068694
# Actual translation:  मुझे एक कप कॉफ़ी चाहिए।
# Predicted translation: मैं मोहन के बाद बस में सैर के सिवाय जब बारिश की सच्चाई पर शक़ है।
# BLEU Score/Accuracy:  0.6529942057256104
# Actual translation:  वह लड़की नहीं चाहती थी कि वह लड़का विदेश जाए।
# Predicted translation: वह अपनी नई गाड़ी नहीं करता था कि उसे किसी से नहीं लौटाए।
# BLEU Score/Accuracy:  0.7389984311706962
# Actual translation:  मैंने उसे बहुत दिनों से नहीं देखा है।
# Predicted translation: मैंने उसे मुश्किल है।
# BLEU Score/Accuracy:  0.8593887047640296
# Actual translation:  मातापिता अपने बच्चों की हिफ़ाज़त के लिए ज़िम्मेदार होते हैं।
# Predicted translation: तुम्हारे पास एक दिन में समय हो रही है।
# BLEU Score/Accuracy:  0.8354534340417261
# Actual translation:  यह मुझे संभालने दो।
# Predicted translation: मुझे लगा कि वह हर आता होगा।
# BLEU Score/Accuracy:  0.7730551756939454
# Actual translation:  उसने खिड़की पर ज़ोर लगाकर खटखटाया।
# Predicted translation: वह पियानो बजाना है।
# BLEU Score/Accuracy:  0.81903625881272
# Actual translation:  वह काम शुरु मत करो।
# Predicted translation: गाड़ी मत करो।
# BLEU Score/Accuracy:  0.8694417438899827
# Actual translation:  नमस्ते।
# Predicted translation: नमस्कार।
# BLEU Score/Accuracy:  0.9036020036098448
# Actual translation:  हमारी मीटिंग कभी-कभार ही टाईम पर शुरू होती है।
# Predicted translation: पौधे बारिश छः बज गई।
# BLEU Score/Accuracy:  0.8091067115702212
# Actual translation:  ये कुत्ते बड़े हैं।
# Predicted translation: आज बादल और समय की जनसंख्या भारत में भूत है।
# BLEU Score/Accuracy:  0.7071067811865476
# Actual translation:  तुम्हे इस किताब का अनुवाद करने में कितना समय लगा?
# Predicted translation: तुम रोज़ कितने बजे घर वापस कर सकते हैं?
# BLEU Score/Accuracy:  0.7952707287670506
# Actual translation:  तुम घर पे हो क्या?
# Predicted translation: आप बाहर नहीं हो?
# BLEU Score/Accuracy:  0.8010548969451144
# Actual translation:  भारत का मौसम इंग्लैड के मौसम से एकसमान नहीं है।
# Predicted translation: दरवाज़े पर बहुत आसान है।
# BLEU Score/Accuracy:  0.7952707287670506
# Actual translation:  उसने गाते गाते काम किया।
# Predicted translation: वह हमेशा काले कपड़े दिया गया।
# BLEU Score/Accuracy:  0.7400828044922853
# Actual translation:  इस दोपहर को मिलते हैं।
# Predicted translation: सम्मेलन कुछ दिन लग गया।
# BLEU Score/Accuracy:  0.7825422900366437
# Actual translation:  मैं बारिश की वजह से आ नहीं पाया।
# Predicted translation: मम्मी ने टॉम को वह किताब को गर्मी के अलावा और मैं अभी तक पहलू से वह किताब को गर्मी के अलावा और मैं अभी तक पहलू
# BLEU Score/Accuracy:  0.616168157487061
# Actual translation:  ताज़ी सब्ज़ियाँ सेहत के लिए अच्छी होतीं हैं।
# Predicted translation: ताज़ी सब्ज़ियाँ स्वास्थ्य के लिए अच्छी होतीं हैं।
# BLEU Score/Accuracy:  0.8323582900575635
# Actual translation:  वह समुंदर की ओर चल रहा था।
# Predicted translation: वह सबका मज़ाक उड़ाता है।
# BLEU Score/Accuracy:  0.7521206186172787
# Actual translation:  बॅटर आऊट हो गया था।
# Predicted translation: पुलीसवाले ने कुछ आदमी को साफ़ किया था।
# BLEU Score/Accuracy:  0.6508911374939451
# Actual translation:  मैं खुशकिसमत था कि सफ़ल हो गया।
# Predicted translation: मेरा घर में ही तक ही तक खाना खाने की तरह की तरह की तरह की तरह की तरह की तरह की तरह की तरह की तरह
# BLEU Score/Accuracy:  0.5358948249862983
# Actual translation:  वह बीमारी की वजह से नहीं आ सका।
# Predicted translation: वह बीमारी की वजह से नहीं आ सका।
# BLEU Score/Accuracy:  0.8408964152537145
# Actual translation:  राजा ने हुक़्म दिया कि क़ैदी को रिहा कर दिया जाए।
# Predicted translation: मरीज़ आँखें बंद कर बिस्टर पर निकले।
# BLEU Score/Accuracy:  0.7751936613371729
# Actual translation:  तुम्हे तुरंत जाना चाहिए।
# Predicted translation: आप थोड़ा धीरे बोल सकते हैं क्या?
# BLEU Score/Accuracy:  0.7016879391277372
# Actual translation:  भारत की राजधानी नई दिल्ली है।
# Predicted translation: इटली की राजधानी रोम है।
# BLEU Score/Accuracy:  0.8408964152537145
# Actual translation:  जन्मदिन मुबारक हो!
# Predicted translation: ग्लास रेत से बनाया जाता है।
# BLEU Score/Accuracy:  0.7311104457090247
# Actual translation:  हमे अंदर जाने से पहले जूते उतारने होंगे।
# Predicted translation: हमें अपने दोस्तों से उसकी बत्तियाँ बंद करना होगा।
# BLEU Score/Accuracy:  0.7636066981663598
# Actual translation:  वह बीमार नहीं हो सकता।
# Predicted translation: वह तीन भाई नहीं सका।
# BLEU Score/Accuracy:  0.8507331335123524
# Actual translation:  उसने आखिरकार सवाल का जवाब ढूँढ निकाला।
# Predicted translation: आखिरकार उसको उसकी माँ हस्पताल में आईं।
# BLEU Score/Accuracy:  0.7598356856515925
# Actual translation:  उसने काम अपने-आप किया।
# Predicted translation: वह बहुत बक-बक करती है।
# BLEU Score/Accuracy:  0.645777692487244
# Actual translation:  वह अफ़वाह पूरी तरह से बेबुनयाद है।
# Predicted translation: इस समस्या के लिए बहुत सारे कष्ट सहने पड़े थे।
# BLEU Score/Accuracy:  0.7427498127683173
# Actual translation:  तुम विदेश जाना चाहती हो क्या?
# Predicted translation: आप ये आओगे क्या?
# BLEU Score/Accuracy:  0.8010548969451144
# Actual translation:  मुझे अगले साल विदेश जाकर पढ़ाई करने का मन है।
# Predicted translation: मैं पियानो बजाना सीख लिया था।
# BLEU Score/Accuracy:  0.7781581271306612
# Actual translation:  मुझे बहुत प्यास लगी है।
# Predicted translation: मुझे आपसे मिलकर अच्छा लगता है।
# BLEU Score/Accuracy:  0.8340313804889192
# Actual translation:  मैं कल कनाडा वापस आऊँगा।
# Predicted translation: मैं कल रहूँगा।
# BLEU Score/Accuracy:  0.9036020036098448
# Actual translation:  दक्षिण टर्मिनल कहाँ पर है?
# Predicted translation: कपड़े बदलने का कमरा कहाँ पर है?
# BLEU Score/Accuracy:  0.798359216893685
# Actual translation:  मुझे याद नहीं।
# Predicted translation: मुझसे और नहीं करूँगा।
# BLEU Score/Accuracy:  0.8408964152537145
# Actual translation:  वो बस से आया था कि ट्रेन से?
# Predicted translation: हमे हड़ताल कर सकते हैं कि वह अपने छाते को गवा नहीं सूझी?
# BLEU Score/Accuracy:  0.6627953568839928
# Actual translation:  यहाँ बेसबॉल खेलना मना है।
# Predicted translation: आप बाहर नहीं लगता है क्या?
# BLEU Score/Accuracy:  0.7377879464668811
# Actual translation:  अपने हाथ अच्छे से धोओ।
# Predicted translation: अपने हाथ धोओ।
# BLEU Score/Accuracy:  0.9621954581957615
# Actual translation:  वह रूसी बोलना और लिखना दोनो जानता है।
# Predicted translation: वह पिछले बहुत सारे शब्दों और कुछ ही कुछ ही कुछ ही कुछ ही कुछ ही कुछ ही कुछ ही कुछ ही कुछ ही कुछ ही कुछ
# BLEU Score/Accuracy:  0.6071873328757825
# Actual translation:  तुम्हें गाड़ी चलाना आता है क्या?
# Predicted translation: तुम गाड़ी चला सकते हो क्या?
# BLEU Score/Accuracy:  0.8827195038481814
# Actual translation:  मुझे समझ में नहीं आ रहा था कि उससे क्या कहूँ।
# Predicted translation: मैं उसके अक्खड़पन अब उससे कहा कि वह कहना और उसके अक्खड़पन अब उससे कहा कि वह कहना और उसके अक्खड़पन अब उससे कहा कि वह कहना
# BLEU Score/Accuracy:  0.5725184614303233
# Actual translation:  इस डब्बे में क्या है?
# Predicted translation: इस और समय में है?
# BLEU Score/Accuracy:  0.8633400213704505
# Actual translation:  वह दस भाषाएँ बोलना जानता है।
# Predicted translation: वह टेस्ट के लिए बेचैन हैं।
# BLEU Score/Accuracy:  0.7801157731069053
# Actual translation:  जब मैं अठारह साल का था मैंने गाड़ी चलानी सीखी और लाईसेंस बनवालिया।
# Predicted translation: मैंने उसे एक ऐसी चीज़ ढूँढ रहा था।
# BLEU Score/Accuracy:  0.8348245638678642
# Actual translation:  मैं रोज़ छः बजे उठता हूँ।
# Predicted translation: मैं हर दूसरे दिन नहाता हूँ।
# BLEU Score/Accuracy:  0.8091067115702212
# Actual translation:  तुम्हें फ़िल्म देखनी चहिए थी।
# Predicted translation: विज्ञान और कुछ नहीं सूझी?
# BLEU Score/Accuracy:  0.7447819789879647
# Actual translation:  लकड़ी से बनी इमारतों में आग आसानी से लग जाती है।
# Predicted translation: कमरे से सोये क्या?
# BLEU Score/Accuracy:  0.8055344092731546
# Actual translation:  हम उसे नहीं जानते हैं।
# Predicted translation: हम उसे नहीं जानते हैं।
# BLEU Score/Accuracy:  0.8832833620110219
# Actual translation:  उम्मीद मत छोड़ो।
# Predicted translation: उनकी यहाँ पर बात कर रहें हैं।
# BLEU Score/Accuracy:  0.6389431042462724
# Actual translation:  मैं तुमसे प्यार करती हूँ।
# Predicted translation: मैं आपसे प्यार करता हूँ।
# BLEU Score/Accuracy:  0.9080865185231703
# Actual translation:  वह काम करती रही।
# Predicted translation: उसने तैरना सीखा।
# BLEU Score/Accuracy:  0.7707713836060629
# Actual translation:  मेरा स्टॉप छूट गया। अगला स्टॉप कितनी देर में आएगा?
# Predicted translation: मैंने उसे सोनी की तरफ़ नष्ट कर दिया।
# BLEU Score/Accuracy:  0.82330698369719
# Actual translation:  आप इसके हित में हैं या नहीं?
# Predicted translation: क्या तुम्हे मुझपर खुशी का स्वाद पसंद है।
# BLEU Score/Accuracy:  0.7503949002834928
# Actual translation:  मुझे दंत चिकित्सक से मिलना है।
# Predicted translation: मुझे बैंक जाना लगता हूँ।
# BLEU Score/Accuracy:  0.8650615454144222
# Actual translation:  मुझे नहीं पता वह लंदन के लिए रवाना कब होएगी।
# Predicted translation: मुझे नहीं पता कि नहीं।
# BLEU Score/Accuracy:  0.8986505734084012
# Actual translation:  उनके पास रहने के लिए कोई घर नहीं है।
# Predicted translation: उन्होंने मेरे लिए अच्छी होतीं हैं।
# BLEU Score/Accuracy:  0.7952707287670506
# Actual translation:  जहाँ भी डालना है डालदो।
# Predicted translation: जहाँ भी रखना है रखदो।
# BLEU Score/Accuracy:  0.8593887047640296
# Actual translation:  झील यहाँ पर बहुत गहरी है।
# Predicted translation: उस आदमी मत भूलना।
# BLEU Score/Accuracy:  0.7598356856515925
# Actual translation:  मेरे अंकल क्रिकेट के शौकिया खिलाड़ी हैं।
# Predicted translation: मेरी एक चर्च हैं।
# BLEU Score/Accuracy:  0.8841583342199357
# Actual translation:  वह आज टीवी पर आएगी।
# Predicted translation: वह दिखने में घंटो के लिए टेक्सी बुलवाई। के पास खुशखबर है।
# BLEU Score/Accuracy:  0.6276299057399732
# Actual translation:  मुझे भरोसा है कि वह अपना वादा निभाएगा।
# Predicted translation: मुझे उससे मदद करने जाऊँगी।
# BLEU Score/Accuracy:  0.8329997998131278
# Actual translation:  मुझे डर था कि तुम मुझे छोड़ दोगे।
# Predicted translation: मुझे आपकी मदद करनी पड़ेगी।
# BLEU Score/Accuracy:  0.816496580927726
# Actual translation:  इस गाड़ी का पिछले दस साल से इस्तेमाल हो रहा है।
# Predicted translation: यह गाड़ी जापान में बहुत सारे कर्ज़ हैं।
# BLEU Score/Accuracy:  0.8074157792118413
# Actual translation:  माँ ने मेरे उनका मज़ाक उड़ाने के लिए डाँट लगाई।
# Predicted translation: मेरे घर को अपनी माँ का निशान
# BLEU Score/Accuracy:  0.7463819494944633
# Actual translation:  उसने पिछले साल स्कूल बदला था।
# Predicted translation: उसे ये निर्भर है।
# BLEU Score/Accuracy:  0.816496580927726
# Actual translation:  चट्टान लगभग बिलकुल सीधी है।
# Predicted translation: गाड़ी होती है।
# BLEU Score/Accuracy:  0.8265168183793802
# Actual translation:  इससे सस्ता वाला है क्या?
# Predicted translation: तुम्हारे कोई भाई के लिए मुश्किल है।
# BLEU Score/Accuracy:  0.7071067811865476
# Actual translation:  वह कौन है?
# Predicted translation: वह किताब है।
# BLEU Score/Accuracy:  0.7875110621102679
# Actual translation:  शब्दकोश (डिक्शनरी) के बिना अंग्रेज़ी की पढ़ाई करना बहुत मुश्किल होगा।
# Predicted translation: कल का आयात होती है।
# BLEU Score/Accuracy:  0.81903625881272
# Actual translation:  तुम्हारी आँखे खराब हैं क्या?
# Predicted translation: आधा किलो अपौइंटमेंट है क्या?
# BLEU Score/Accuracy:  0.8020396005825877
# Actual translation:  गाँव में सीधे जाते रहिए।
# Predicted translation: एक घर को खाना खाने से एक बड़ा थी।
# BLEU Score/Accuracy:  0.6964705665515708
# Actual translation:  मुझसे कोई भी सवाल पूछने में न हिचकिचाएँ।
# Predicted translation: तुम अमीर हो सकती।
# BLEU Score/Accuracy:  0.8408964152537145
# Actual translation:  तुम्हारे दिमाग़ में यह बात कैसे आई?
# Predicted translation: तुमने क्या किया?
# BLEU Score/Accuracy:  0.8968833070917552
# Actual translation:  दुनिया भर में बहुत से लोगों को अच्छा पानी उपलब्ध नहीं है।
# Predicted translation: समिति के लिए दूसरे देशों पर निर्भर है।
# BLEU Score/Accuracy:  0.8354534340417261
# Actual translation:  मैं तुमसे ज़्यादा सुंदर हूँ।
# Predicted translation: मैं तुमसे ज़्यादा खूबसूरत हूँ।
# BLEU Score/Accuracy:  0.8848058325185321
# Actual translation:  बाद में मिलेंगे।
# Predicted translation: फिर मिलेंगे।
# BLEU Score/Accuracy:  0.8857000285382948
# Actual translation:  इसे दोबारा पढ़ें।
# Predicted translation: एक दिन में चौबीस घंटे होते हैं।
# BLEU Score/Accuracy:  0.7071067811865476
# Actual translation:  वह बहुत ध्यानपूर्वक है, इसलिए बहुत कम ग़लतियाँ करती है।
# Predicted translation: उसके पास मेरे कोई लेना-देना नहीं थे।
# BLEU Score/Accuracy:  0.7546487907970829
# Actual translation:  कल मेरा जन्मदिन है।
# Predicted translation: कल मेरा जन्मदिन था।
# BLEU Score/Accuracy:  0.8979007600118484
# Actual translation:  उसे शायद अपनी नौकरी अगले महीने छोड़नी पड़ेगी।
# Predicted translation: उसने लाल ही का घर में रह रही है।
# BLEU Score/Accuracy:  0.7922410709252884
# Actual translation:  मेरे पिता शायद सो रहे होंगे।
# Predicted translation: मेरे पापा पहनी है!
# BLEU Score/Accuracy:  0.7790872728179328
# Actual translation:  इसको अपना घर ही समझिए।
# Predicted translation: अपना वादा मत तोड़ो।
# BLEU Score/Accuracy:  0.7952707287670506
# Actual translation:  क्या आज कोई अनुपस्थित है?
# Predicted translation: आज कोई है जो नहीं आया है?
# BLEU Score/Accuracy:  0.8242367502646054
# Actual translation:  वह एक बहुत ही खूबसूरत औरत है।
# Predicted translation: वह मुझे बहुत बक-बक के लिए बहुत पैसे कमाता है।
# BLEU Score/Accuracy:  0.6992922471483762
# Actual translation:  मुझे तुमसे किसी बारे में बात करनी है।
# Predicted translation: कारोबार में स्वतंत्रता प्राप्त खराब हो गई होती है।
# BLEU Score/Accuracy:  0.7238348098810832
# Actual translation:  उसने लिफ़ाफ़े को काटकर खोल दिया।
# Predicted translation: वह हफ़्ते से से से से से से से से से से से से से से से से से से से से से से से से से
# BLEU Score/Accuracy:  0.4924790605054523
# Actual translation:  हाँ। यह सही है।
# Predicted translation: तुम्हे टॉम को आना सा चाहिए।
# BLEU Score/Accuracy:  0.6500593260343692
# Actual translation:  मुझे अब चाबी मिल सकती है क्या?
# Predicted translation: क्या हूँ क्या?
# BLEU Score/Accuracy:  0.8265168183793802
# Actual translation:  मुझे किसी के खटखटाने की आवाज़ सुनाई दी।
# Predicted translation: मैंने उस औरत को गस्सा दिलाया।
# BLEU Score/Accuracy:  0.7598356856515925
# Overall Average Accuracy:  0.7755695667277036

# %% [markdown]
# I just tried the BLEU score as it is used to check the translation accuracy but I am not sure if the scores are correct. Even for perfect translation the score was not maximum.

# %% [markdown]
#     Actual translation:  चिड़ियाँ घोसले बनातीं हैं।
#     Predicted translation: पक्षी घोसले बनातें हैं।
#     Actual translation:  बाद में मिलेंगे।
#     Predicted translation: फिर मिलेंगे।
#
#     The above translated text amaze me as they have one word different but still the meaning is same. There are many such examples.

# %% [markdown]
# # Results
#
# ---
# * Which parts of the sentence are used as a token? Each character, each word, or are some words split up? - Each word is used as a token. Every unique word is represented by unique token.
# * Do the same tokens in different language have the same ID?
# e.g. Would the same token index map to the German word die and to the English word die? - Yes, There's possiblity of getting same token ID for two same words in different language. Depending on the position of the word in both the languages.
# * What is the relation between the encoder output and the encoder hidden state which is used to initialize the decoder hidden state?
# (for the architecture used in the tutorial) - It is used to generate the attention weights
# * Is the decoder attending to all previous positions, including the previous decoder predictions? - Yes
# * Does the Encoder output change in different decoding steps? - No it remains the same.
# * Does the context vector change in different decoding steps? - Yes it does
# * The decoder uses teacher forcing. Does this mean the time steps can be computed in parallel? - Yes, as we already know what the output will be, so while training it can be computed parallelly
# * Why is a mask applied to the loss function? - As the input are padded to make them equal size, we need to apply mask to avoid the padded input during calculation of loss

# %% [markdown]
# # Conclusion
#
# ---
# I found dot product to be the better attention mechanism , considering this language. As I got better result with dot product compare to other mechanism.
# The model was able to attend to correct token most of the time.
